# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.28.1-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 72.5 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.11.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 26.1 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.10.31)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 64.1 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.0.12)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.13.4 tokenizers-0.13.3 transformers-4.28.1

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from transformers import BertTokenizer, TFBertForSequenceClassification
from sklearn.model_selection import train_test_split

# %%
# Load the IMDB dataset from CSV
df = pd.read_csv('/content/drive/MyDrive/IMDB_Dataset.csv', encoding='utf-8',on_bad_lines='skip')

# %%
test_df = pd.read_csv('/content/drive/MyDrive/movie-review-dataset.csv', on_bad_lines='skip')

# %%
print(len(test_df))
# Out:
# 609

# %%
df['sentiment'] = df['sentiment'].replace({'positive': 1, 'negative': 0})

print(df.head(20))
# Out:
#                                                review  sentiment
# 0   One of the other reviewers has mentioned that ...          1
# 1   A wonderful little production. <br /><br />The...          1
# 2   I thought this was a wonderful way to spend ti...          1
# 3   Basically there's a family where a little boy ...          0
# 4   Petter Mattei's "Love in the Time of Money" is...          1
# 5   Probably my all-time favorite movie, a story o...          1
# 6   I sure would like to see a resurrection of a u...          1
# 7   This show was an amazing, fresh & innovative i...          0
# 8   Encouraged by the positive comments about this...          0
# 9   If you like original gut wrenching laughter yo...          1
# 10  Phil the Alien is one of those quirky films wh...          0
# 11  I saw this movie when I was about 12 when it c...          0
# 12  So im not a big fan of Boll's work but then ag...          0
# 13  The cast played Shakespeare.<br /><br />Shakes...          0
# 14  This a fantastic movie of three prisoners who ...          1
# 15  Kind of drawn in by the erotic scenes, only to...          0
# 16  Some films just simply should not be remade. T...          1
# 17  This movie made it into one of my top 10 most ...          0
# 18  I remember this film,it was the first film i h...          1
# 19  An awful film! It must have been up against so...          0

# %%
# Preprocess the text column
import re
import pandas as pd
import numpy as np
def preprocess_text(text):
    # Convert to lowercase
    text = text.lower()
    # Remove html tags
    text = re.sub('<[^<]+?>', '', text)
    # Remove punctuation
    text = re.sub(r'[^\w\s]', '', text)
    # Remove numbers
    text = re.sub(r'\d+', '', text)
    # Remove extra whitespace
    text = ' '.join(text.split())
    return text

df['review'] = df['review'].apply(preprocess_text)

# %%
df1 = df[df['review'].str.split().str.len() < 100]

print(df1.head(10))
# Out:
#                                                review  sentiment
# 9   if you like original gut wrenching laughter yo...          1
# 10  phil the alien is one of those quirky films wh...          0
# 14  this a fantastic movie of three prisoners who ...          1
# 22  what an absolutely stunning movie if you have ...          1
# 36  the plot is about the death of little children...          0
# 46  protocol is an implausible movie whose only sa...          0
# 49  average and surprisingly tame fulci giallo whi...          0
# 53  i cannot believe i enjoyed this as much as i d...          1
# 62  so lets beginthe movie itself is as original a...          1
# 63  besides being boring the scenes were oppressiv...          0

# %%
print(len(df1))
# Out:
# 6510

# %%
# Define tokenizer
import transformers
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
# Out:
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]

# %%
# Tokenize train dataset
import torch
# Tokenize train dataset
train_encodings = tokenizer(list(df1['review']), padding=True, truncation=True, max_length=100)
X_train = train_encodings['input_ids']
y_train = np.array(list(df1['sentiment']))
print(len(X_train))
print(len(y_train))
# Out:
# 6510
# 6510

# %%
# Tokenize test dataset
test_encodings = tokenizer(list(test_df['review']), padding=True, truncation=True, max_length=100)
X_val = test_encodings['input_ids']
y_val = np.array(list(test_df['sentiment']))

# %%
from transformers import TFBertForSequenceClassification

# Load saved model
model_path = '/content/drive/MyDrive/Model/Model-PreTrained'
model = TFBertForSequenceClassification.from_pretrained(model_path)
# Load the BERT tokenizer
# tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
# Out:
# Some layers from the model checkpoint at /content/drive/MyDrive/Model/Model-PreTrained were not used when initializing TFBertForSequenceClassification: ['dropout_75']
# - This IS expected if you are initializing TFBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFBertForSequenceClassification were initialized from the model checkpoint at /content/drive/MyDrive/Model/Model-PreTrained.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertForSequenceClassification for predictions without further training.

# %%
# Compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=2e-5, epsilon=1e-08)
loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
metric = tf.keras.metrics.SparseCategoricalAccuracy('accuracy')
model.compile(optimizer=optimizer, loss=loss, metrics=[metric])

# %%
# Train the model
train_dataset = tf.data.Dataset.from_tensor_slices((
    {"input_ids": X_train, "attention_mask": np.ones_like(X_train)},
    y_train
))
train_dataset = train_dataset.shuffle(len(X_train)).batch(32)

# %%
val_dataset = tf.data.Dataset.from_tensor_slices((
    {"input_ids": X_val, "attention_mask": np.ones_like(X_val)},
    y_val
))
val_dataset = val_dataset.batch(32)

# %%
# Evaluate the model on the validation dataset
results = model.evaluate(val_dataset)

# Print the accuracy
print(f"Accuracy: {results[1]*100:.2f}%")
# Out:
# 20/20 [==============================] - 59s 2s/step - loss: 0.1477 - accuracy: 0.9639
# Accuracy: 96.39%

# %%
# !pip install --upgrade textattack
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting textattack
#   Downloading textattack-0.3.8-py3-none-any.whl (418 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 418.7/418.7 kB 14.3 MB/s eta 0:00:00
# Collecting bert-score>=0.3.5
#   Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from textattack) (3.11.0)
# Collecting pycld2
#   Downloading pycld2-0.41.tar.gz (41.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.4/41.4 MB 19.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch!=1.8,>=1.7.0 in /usr/local/lib/python3.9/dist-packages (from textattack) (2.0.0+cu118)
# Collecting click<8.1.0
#   Downloading click-8.0.4-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.5/97.5 kB 14.0 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from textattack) (4.65.0)
# Collecting OpenHowNet
#   Downloading OpenHowNet-2.0-py3-none-any.whl (18 kB)
# Collecting num2words
#   Downloading num2words-0.5.12-py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.2/125.2 kB 19.5 MB/s eta 0:00:00
# Collecting flair
#   Downloading flair-0.12.2-py3-none-any.whl (373 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 373.1/373.1 kB 42.1 MB/s eta 0:00:00
# Collecting lemminflect
#   Downloading lemminflect-0.2.3-py3-none-any.whl (769 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 769.7/769.7 kB 64.4 MB/s eta 0:00:00
# Collecting language-tool-python
#   Downloading language_tool_python-2.7.1-py3-none-any.whl (34 kB)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.9/dist-packages (from textattack) (9.1.0)
# Requirement already satisfied: editdistance in /usr/local/lib/python3.9/dist-packages (from textattack) (0.6.2)
# Collecting lru-dict
#   Downloading lru_dict-1.1.8-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (28 kB)
# Collecting word2number
#   Downloading word2number-1.1.zip (9.7 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.9/dist-packages (from textattack) (1.22.4)
# Collecting terminaltables
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: transformers>=4.21.0 in /usr/local/lib/python3.9/dist-packages (from textattack) (4.28.1)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from textattack) (1.10.1)
# Requirement already satisfied: jieba in /usr/local/lib/python3.9/dist-packages (from textattack) (0.42.1)
# Collecting pinyin==0.4.0
#   Downloading pinyin-0.4.0.tar.gz (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 81.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (from textattack) (3.8.1)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from textattack) (1.5.3)
# Collecting datasets==2.4.0
#   Downloading datasets-2.4.0-py3-none-any.whl (365 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 365.7/365.7 kB 42.7 MB/s eta 0:00:00
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.9/dist-packages (from textattack) (1.7.1)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in /usr/local/lib/python3.9/dist-packages (from datasets==2.4.0->textattack) (0.13.4)
# Collecting dill<0.3.6
#   Downloading dill-0.3.5.1-py2.py3-none-any.whl (95 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.8/95.8 kB 12.9 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.9/dist-packages (from datasets==2.4.0->textattack) (2.27.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from datasets==2.4.0->textattack) (23.1)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.9/dist-packages (from datasets==2.4.0->textattack) (9.0.0)
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 68.3 MB/s eta 0:00:00
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 kB 27.5 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.9/dist-packages (from datasets==2.4.0->textattack) (2023.4.0)
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py39-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 kB 20.1 MB/s eta 0:00:00
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from bert-score>=0.3.5->textattack) (3.7.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0.1->textattack) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0.1->textattack) (2.8.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch!=1.8,>=1.7.0->textattack) (3.1.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch!=1.8,>=1.7.0->textattack) (4.5.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch!=1.8,>=1.7.0->textattack) (3.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch!=1.8,>=1.7.0->textattack) (2.0.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch!=1.8,>=1.7.0->textattack) (1.11.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch!=1.8,>=1.7.0->textattack) (16.0.1)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch!=1.8,>=1.7.0->textattack) (3.25.2)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from transformers>=4.21.0->textattack) (0.13.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers>=4.21.0->textattack) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers>=4.21.0->textattack) (2022.10.31)
# Collecting ftfy
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 7.5 MB/s eta 0:00:00
# Collecting janome
#   Downloading Janome-0.4.2-py2.py3-none-any.whl (19.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 79.4 MB/s eta 0:00:00
# Collecting segtok>=1.5.7
#   Downloading segtok-1.5.11-py3-none-any.whl (24 kB)
# Collecting boto3
#   Downloading boto3-1.26.116-py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.6/135.6 kB 19.5 MB/s eta 0:00:00
# Requirement already satisfied: tabulate in /usr/local/lib/python3.9/dist-packages (from flair->textattack) (0.8.10)
# Collecting pptree
#   Downloading pptree-3.1.tar.gz (3.0 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: hyperopt>=0.2.7 in /usr/local/lib/python3.9/dist-packages (from flair->textattack) (0.2.7)
# Requirement already satisfied: gensim>=3.8.0 in /usr/local/lib/python3.9/dist-packages (from flair->textattack) (4.3.1)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.9/dist-packages (from flair->textattack) (1.2.2)
# Collecting mpld3==0.3
#   Downloading mpld3-0.3.tar.gz (788 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 788.5/788.5 kB 64.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting wikipedia-api
#   Downloading Wikipedia_API-0.5.8-py3-none-any.whl (13 kB)
# Collecting gdown==4.4.0
#   Downloading gdown-4.4.0.tar.gz (14 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (from flair->textattack) (4.9.2)
# Collecting langdetect
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 54.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pytorch-revgrad
#   Downloading pytorch_revgrad-0.2.0-py3-none-any.whl (4.6 kB)
# Collecting sqlitedict>=1.6.0
#   Downloading sqlitedict-2.1.0.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Collecting deprecated>=1.2.4
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Collecting transformer-smaller-training-vocab>=0.2.1
#   Downloading transformer_smaller_training_vocab-0.2.3-py3-none-any.whl (12 kB)
# Collecting conllu>=4.0
#   Downloading conllu-4.5.2-py2.py3-none-any.whl (16 kB)
# Collecting bpemb>=0.3.2
#   Downloading bpemb-0.3.4-py3-none-any.whl (19 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from gdown==4.4.0->flair->textattack) (4.11.2)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from gdown==4.4.0->flair->textattack) (1.16.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from nltk->textattack) (1.2.0)
# Collecting docopt>=0.6.2
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from OpenHowNet->textattack) (67.6.1)
# Collecting anytree
#   Downloading anytree-2.8.0-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 6.1 MB/s eta 0:00:00
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.98-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 83.4 MB/s eta 0:00:00
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.9/dist-packages (from deprecated>=1.2.4->flair->textattack) (1.14.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets==2.4.0->textattack) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets==2.4.0->textattack) (2.0.12)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 kB 22.0 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 14.2 MB/s eta 0:00:00
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 kB 31.6 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.9/dist-packages (from gensim>=3.8.0->flair->textattack) (6.3.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.9/dist-packages (from hyperopt>=0.2.7->flair->textattack) (2.2.1)
# Requirement already satisfied: future in /usr/local/lib/python3.9/dist-packages (from hyperopt>=0.2.7->flair->textattack) (0.18.3)
# Requirement already satisfied: py4j in /usr/local/lib/python3.9/dist-packages (from hyperopt>=0.2.7->flair->textattack) (0.10.9.7)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->bert-score>=0.3.5->textattack) (5.12.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->bert-score>=0.3.5->textattack) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->bert-score>=0.3.5->textattack) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->bert-score>=0.3.5->textattack) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->bert-score>=0.3.5->textattack) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->bert-score>=0.3.5->textattack) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->bert-score>=0.3.5->textattack) (4.39.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets==2.4.0->textattack) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets==2.4.0->textattack) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets==2.4.0->textattack) (2022.12.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.21.3->flair->textattack) (3.1.0)
# Collecting protobuf<=3.20.2
#   Downloading protobuf-3.20.2-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 60.9 MB/s eta 0:00:00
# Collecting s3transfer<0.7.0,>=0.6.0
#   Downloading s3transfer-0.6.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.6/79.6 kB 12.1 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting botocore<1.30.0,>=1.29.116
#   Downloading botocore-1.29.116-py3-none-any.whl (10.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.6/10.6 MB 111.6 MB/s eta 0:00:00
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.9/dist-packages (from ftfy->flair->textattack) (0.2.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch!=1.8,>=1.7.0->textattack) (2.1.2)
# Collecting multiprocess
#   Downloading multiprocess-0.70.13-py39-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.3/132.3 kB 19.6 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch!=1.8,>=1.7.0->textattack) (1.3.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->bert-score>=0.3.5->textattack) (3.15.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4->gdown==4.4.0->flair->textattack) (2.4.1)
# Building wheels for collected packages: pinyin, gdown, mpld3, pycld2, word2number, docopt, sqlitedict, langdetect, pptree
#   Building wheel for pinyin (setup.py) ... done
#   Created wheel for pinyin: filename=pinyin-0.4.0-py3-none-any.whl size=3630492 sha256=d7972d029bee6f99ba1a65755c1a78ec595735325d1047ae2611edf9b3781167
#   Stored in directory: /root/.cache/pip/wheels/91/4d/03/beb69f9530864b62f295333257151b845f5f871b9a32665b9e
#   Building wheel for gdown (pyproject.toml) ... done
#   Created wheel for gdown: filename=gdown-4.4.0-py3-none-any.whl size=14776 sha256=a6384b4210338c126850450728dfdc4138ab869e049a0a6704231e47dea6d526
#   Stored in directory: /root/.cache/pip/wheels/7d/37/b6/b2a79c75e898c0b8e46ff255102602d7159a10d9af0d80641a
#   Building wheel for mpld3 (setup.py) ... done
#   Created wheel for mpld3: filename=mpld3-0.3-py3-none-any.whl size=116702 sha256=c06ebf092652492d1cc5eb1dbba1c66f992f3080e3b49beaf18664ca2fe8b269
#   Stored in directory: /root/.cache/pip/wheels/a6/f4/e6/e40ff9021f6b3854af70fa8ea004f5ab95672817462df08fed
#   Building wheel for pycld2 (setup.py) ... done
#   Created wheel for pycld2: filename=pycld2-0.41-cp39-cp39-linux_x86_64.whl size=9915701 sha256=62491ca35ffff160ed74b626451042a1fad5df998337dd13ad31b80c27227965
#   Stored in directory: /root/.cache/pip/wheels/ed/98/60/230df7a9368a02bf62e0e2719a31615b2aa82238dea526b637
#   Building wheel for word2number (setup.py) ... done
#   Created wheel for word2number: filename=word2number-1.1-py3-none-any.whl size=5582 sha256=9199d9f648f80f2d7b88ad0f20509dd26b61c61dd146a0198d1e746669861b2e
#   Stored in directory: /root/.cache/pip/wheels/a0/4a/5b/d2f2df5c344ddbecb8bea759872c207ea91d93f57fb54e816e
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13721 sha256=41cff2bd0d1f30ed24f9cb4913c72eda09313d99e2095222eb4d9e38a946caae
#   Stored in directory: /root/.cache/pip/wheels/70/4a/46/1309fc853b8d395e60bafaf1b6df7845bdd82c95fd59dd8d2b
#   Building wheel for sqlitedict (setup.py) ... done
#   Created wheel for sqlitedict: filename=sqlitedict-2.1.0-py3-none-any.whl size=16863 sha256=5fef2d40d3d58b6cde9ca48c875b0c284e0c0675d5d94ebcf85ce7b2aacec213
#   Stored in directory: /root/.cache/pip/wheels/f6/48/c4/942f7a1d556fddd2348cb9ac262f251873dfd8a39afec5678e
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993243 sha256=f058c97eab6e4e4bd84034676b071a144a4dab8a86682d045301a6bc4fa4851b
#   Stored in directory: /root/.cache/pip/wheels/d1/c1/d9/7e068de779d863bc8f8fc9467d85e25cfe47fa5051fff1a1bb
#   Building wheel for pptree (setup.py) ... done
#   Created wheel for pptree: filename=pptree-3.1-py3-none-any.whl size=4629 sha256=bb62b21afa6be9212918dc48a451911706e40be44001849106b9fbc747d70fa9
#   Stored in directory: /root/.cache/pip/wheels/52/0e/51/514e690004ea9713bc3fdb678d5e2768fcc597d0c3b6a3abd2
# Successfully built pinyin gdown mpld3 pycld2 word2number docopt sqlitedict langdetect pptree
# Installing collected packages: word2number, sqlitedict, sentencepiece, pycld2, pptree, pinyin, mpld3, lru-dict, janome, docopt, xxhash, terminaltables, segtok, protobuf, num2words, multidict, lemminflect, langdetect, jmespath, ftfy, frozenlist, dill, deprecated, conllu, click, async-timeout, anytree, yarl, wikipedia-api, responses, OpenHowNet, multiprocess, language-tool-python, botocore, aiosignal, s3transfer, gdown, bpemb, aiohttp, boto3, datasets, transformer-smaller-training-vocab, pytorch-revgrad, flair, bert-score, textattack
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: click
#     Found existing installation: click 8.1.3
#     Uninstalling click-8.1.3:
#       Successfully uninstalled click-8.1.3
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.6.6
#     Uninstalling gdown-4.6.6:
#       Successfully uninstalled gdown-4.6.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.12.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 3.20.2 which is incompatible.
# tensorflow-metadata 1.13.1 requires protobuf<5,>=3.20.3, but you have protobuf 3.20.2 which is incompatible.
# Successfully installed OpenHowNet-2.0 aiohttp-3.8.4 aiosignal-1.3.1 anytree-2.8.0 async-timeout-4.0.2 bert-score-0.3.13 boto3-1.26.116 botocore-1.29.116 bpemb-0.3.4 click-8.0.4 conllu-4.5.2 datasets-2.4.0 deprecated-1.2.13 dill-0.3.5.1 docopt-0.6.2 flair-0.12.2 frozenlist-1.3.3 ftfy-6.1.1 gdown-4.4.0 janome-0.4.2 jmespath-1.0.1 langdetect-1.0.9 language-tool-python-2.7.1 lemminflect-0.2.3 lru-dict-1.1.8 mpld3-0.3 multidict-6.0.4 multiprocess-0.70.13 num2words-0.5.12 pinyin-0.4.0 pptree-3.1 protobuf-3.20.2 pycld2-0.41 pytorch-revgrad-0.2.0 responses-0.18.0 s3transfer-0.6.0 segtok-1.5.11 sentencepiece-0.1.98 sqlitedict-2.1.0 terminaltables-3.1.10 textattack-0.3.8 transformer-smaller-training-vocab-0.2.3 wikipedia-api-0.5.8 word2number-1.1 xxhash-3.2.0 yarl-1.8.2

# %%
# !pip show textattack
# Out:
# Name: textattack
# Version: 0.3.8
# Summary: A library for generating text adversarial examples
# Home-page: https://github.com/QData/textattack
# Author: QData Lab at the University of Virginia
# Author-email: jm8wx@virginia.edu
# License: MIT
# Location: /usr/local/lib/python3.9/dist-packages
# Requires: bert-score, click, datasets, editdistance, filelock, flair, jieba, language-tool-python, lemminflect, lru-dict, more-itertools, nltk, num2words, numpy, OpenHowNet, pandas, pinyin, pycld2, PySocks, scipy, terminaltables, torch, tqdm, transformers, word2number
# Required-by:

# %%
import textattack.attack_recipes as attack_recipes

# Get a list of all the methods and attributes in attack_recipes.
methods = [method for method in dir(attack_recipes) if callable(getattr(attack_recipes, method))]

# Print the list of methods.
print(methods)
# Out:
# textattack: Updating TextAttack package dependencies.
# textattack: Downloading NLTK required packages.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package omw to /root/nltk_data...
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Unzipping taggers/universal_tagset.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ['A2TYoo2021', 'AttackRecipe', 'BAEGarg2019', 'BERTAttackLi2020', 'CLARE2020', 'CheckList2020', 'DeepWordBugGao2018', 'FasterGeneticAlgorithmJia2019', 'FrenchRecipe', 'GeneticAlgorithmAlzantot2018', 'HotFlipEbrahimi2017', 'IGAWang2019', 'InputReductionFeng2018', 'Kuleshov2017', 'MorpheusTan2020', 'PSOZang2020', 'PWWSRen2019', 'Pruthi2019', 'Seq2SickCheng2018BlackBox', 'SpanishRecipe', 'TextBuggerLi2018', 'TextFoolerJin2019']

# %%
import torch
import transformers
import textattack
import transformers
from textattack.models.wrappers import HuggingFaceModelWrapper
from textattack.attack_recipes import Seq2SickCheng2018BlackBox
from textattack.attack_recipes import Pruthi2019
from transformers import BertForSequenceClassification, BertTokenizer
from textattack.models.wrappers import HuggingFaceModelWrapper
from textattack.models.wrappers import ModelWrapper
import numpy as np

# %%
class MyModelWrapper(ModelWrapper):
    def __init__(self, model, tokenizer):
        self.model = model
        self.tokenizer = tokenizer
        
    def __call__(self, text_input_list):
        input_ids = []
        token_type_ids = []
        attention_mask = []
        for text_input in text_input_list:
            input_dict = self.tokenizer.encode_plus(text_input, add_special_tokens=True, max_length=512, pad_to_max_length=True)
            input_ids.append(input_dict['input_ids'])
            token_type_ids.append(input_dict['token_type_ids'])
            attention_mask.append(input_dict['attention_mask'])
            
        input_ids = np.array(input_ids)
        token_type_ids = np.array(token_type_ids)
        attention_mask = np.array(attention_mask)
        outputs = self.model([input_ids, token_type_ids, attention_mask], training=False)
        logits = outputs[0]
        return logits.numpy()

# %%
model_wrapper = MyModelWrapper(model, tokenizer)

# %%
# Initialize the TextFooler attack recipe
attack = Pruthi2019.build(model_wrapper)
# Out:
# textattack: Unknown if model of class <class 'transformers.models.bert.modeling_tf_bert.TFBertForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.

# %%
# test_df.columns = ['review', 'sentiment']
# test_df.to_csv('test1.csv', index=False)
texts = np.array(test_df['review'])
labels = np.array(test_df['sentiment'])

# %%
text = texts[0]
label = labels[0]
results_iterable = attack.attack(text, ground_truth_output=int(label))
adv_text = results_iterable.perturbed_text()

print(adv_text)
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# /usr/local/lib/python3.9/dist-packages/transformers/tokenization_utils_base.py:2354: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# This movie was grReat!

# %%
adv_texts = []
for text, label in zip(texts, labels):
    results_iterable = attack.attack(text, ground_truth_output=int(label))
    if hasattr(results_iterable, "__iter__"):
        for result in results_iterable:
            adv_text = results_iterable.perturbed_text()
            adv_texts.append(adv_text)
            print(f"Adversarial example: {adv_text}")
    else:
        adv_text = results_iterable.perturbed_text()
        adv_texts.append(adv_text)
        print(f"Adversarial example: {adv_text}")
# Out:
# Adversarial example: This movie was grfat!
# Adversarial example: The acting was terribrle
# Adversarial example: I loved this fiim
# Adversarial example: It was a wsate of time
# Adversarial example: The plot was predkctable
# Adversarial example: This is a mudt-watch movie
# Adversarial example: I would not rdcommend this movie
# Adversarial example: The cinematography was stuning
# Adversarial example: The script was weHak
# Adversarial example: The ending was dksappointing
# Adversarial example: This is the best move ever!
# Adversarial example: I regeet watching this film
# Adversarial example: The caracters were well-developed
# Adversarial example: It was too sliw-paced
# Adversarial example: I was on the edge of my seat the whole time
# Adversarial example: The special effects were ajazing
# Adversarial example: I was borwd throughout the entire movie
# Adversarial example: The soundtrack was bautiful
# Adversarial example: The dialogue was cehesy
# Adversarial example: I would watch this movie again and again
# Adversarial example: The story was compleling
# Adversarial example: It was a complete dQisaster
# Adversarial example: The direction was shperb
# Adversarial example: I couldn't stahd this movie
# Adversarial example: The cast did a fatastic job
# Adversarial example: It was a total waste of moXney
# Adversarial example: The film was though-tprovoking
# Adversarial example: I didn't understxnd the plot
# Adversarial example: The editing was well done
# Adversarial example: This move made me cry
# Adversarial example: It was a mund-bending experience
# Adversarial example: I was djsappointed by this film
# Adversarial example: The humor was soot-on
# Adversarial example: I would not rfcommend this to anyone
# Adversarial example: The production design was outstanring
# Adversarial example: I couldn't tzke this movie seriously
# Adversarial example: The acting was penomenal
# Adversarial example: It was a bit too lkng
# Adversarial example: The mivie kept me engaged the entire time
# Adversarial example: I wish I had not seen this movie
# Adversarial example: The story was odiginal and refreshing
# Adversarial example: It was a complete letdoen
# Adversarial example: The score was perfeft
# Adversarial example: I couldn't conenct with the characters
# Adversarial example: The film was visually shunning
# Adversarial example: I fell aleep during this movie
# Adversarial example: The chemistry between the actors was aYmazing
# Adversarial example: It was a wasye of my time and money
# Adversarial example: The pacing was perfect
# Adversarial example: I was very djsappointed in this film
# Adversarial example: The suspense was throlling
# Adversarial example: This movie was a mastedpiece
# Adversarial example: I found the plot to be confysing
# Adversarial example: The acting was mdeiocre
# Adversarial example: I was pleasantly surprised by this flim
# Adversarial example: The special effects were lakcluster
# Adversarial example: I was blown away by this movie
# Adversarial example: The fuilm was too long
# Adversarial example: The characters were one-dimensional
# Adversarial example: The direction was mdeiocre
# Adversarial example: I couldn't shand the soundtrack
# Adversarial example: The movie was too soow
# Adversarial example: The plot was clidhé
# Adversarial example: The cinematography was mdeiocre
# Adversarial example: I was entrrtained throughout the entire film
# Adversarial example: The acting was wYooden
# Adversarial example: The film was too predictaboe
# Adversarial example: The dialogue was crjnge-worthy
# Adversarial example: The special effects were chesey
# Adversarial example: The pacihg was too fast
# Adversarial example: This movie was a washe of time and money
# Adversarial example: The directiqon was lackluster
# Adversarial example: I loevd this movie from start to finish
# Adversarial example: The plot was convoputed
# Adversarial example: The acting was surperb
# Adversarial example: I was disappointed by the endijg
# Adversarial example: The soundtrack was foUrgettable
# Adversarial example: The film was beauBtifully shot
# Adversarial example: I couldn't get into this mpvie
# Adversarial example: The script was bripliant
# Adversarial example: The editing was chkppy
# Adversarial example: I was completely inbvested in this film
# Adversarial example: Loved it! Best move ever.
# Adversarial example: Wlrst movie I've ever seen.
# Adversarial example: Throlling action and suspense throughout.
# Adversarial example: Grezt movie!
# Adversarial example: Wkrst film ever.
# Adversarial example: I lovPed it!
# Adversarial example: Terrjble acting ruins this one.
# Adversarial example: Awfsome film!
# Adversarial example: Don't waste your tlme.
# Adversarial example: Increfible performance by the lead actor.
# Adversarial example: Excellet direction and cinematography.
# Adversarial example: Dreuadful dialogue ruins this film.
# Adversarial example: The bdst movie I've seen all year.
# Adversarial example: I couldn't stznd it.
# Adversarial example: Impresive special effects.
# Adversarial example: A complete waqte of money.
# Adversarial example: Highly recomnended!
# Adversarial example: I wouldn't recommend this to anyone.
# Adversarial example: This movie was fanhastic!
# Adversarial example: The acting was meiocre but the plot was intriguing.
# Adversarial example: I was on the edge of my seat the entire time.
# Adversarial example: I thought the ending was lckluster.
# Adversarial example: The special effects were ajazing.
# Adversarial example: The cinematography was beautiful.
# Adversarial example: I couldn't foilow the plot.
# Adversarial example: The humor fekl flat.
# Adversarial example: I can't wsit to watch it again!
# Adversarial example: The story was capfivating.
# Adversarial example: The cyaracters were well-developed.
# Adversarial example: I didn't czre about any of the characters.
# Adversarial example: The dialogue was witty.
# Adversarial example: The pacing was slpw.
# Adversarial example: I loved the soundfrack.
# Adversarial example: The costume design was stuning.
# Adversarial example: I found the movie confuslng.
# Adversarial example: The visuals were breaghtaking.
# Adversarial example: The script was uxninspired.
# Adversarial example: The acting was superb.
# Adversarial example: I couldn't look away.
# Adversarial example: The direction was too-notch.
# Adversarial example: The writing was weqk.
# Adversarial example: The twists kept me guessing.
# Adversarial example: The CGI was impreAssive.
# Adversarial example: I was borfd from start to finish.
# Adversarial example: I didn't uncerstand the point of the movie.
# Adversarial example: I was completely invested in the shory.
# Adversarial example: The score was hauntingly bautiful.
# Adversarial example: The themes were thoughy-provoking.
# Adversarial example: I thought the acting was ovrerated.
# Adversarial example: The ending was predictanle.
# Adversarial example: The set design was impreasive.
# Adversarial example: I didn't cre about the story.
# Adversarial example: The tension was palpable.
# Adversarial example: The movie was too ling.
# Adversarial example: The characters were one-dimensionql.
# Adversarial example: The cinematography was too dzrk.
# Adversarial example: The humor was too jkvenile.
# Adversarial example: I was moved to tears.
# Adversarial example: The special effects were oveursed.
# Adversarial example: I couldn't connfct with the characters.
# Adversarial example: The story fexlt disjointed.
# Adversarial example: The pwcing was too slow for my taste.
# Adversarial example: I lived the chemistry between the actors.
# Adversarial example: The costumes were distractjng.
# Adversarial example: I felt emotionally drained after watching.
# Adversarial example: The dialogue was stitled.
# Adversarial example: The plot was thkn.
# Adversarial example: The cinematography was too bysy.
# Adversarial example: The story was odiginal.
# Adversarial example: I thought the movie was forgXettable.
# Adversarial example: The acting was wooYden.
# Adversarial example: The plot twists were pBoorly executed.
# Adversarial example: I couldn't suspend my dsibelief.
# Adversarial example: The editing was slkppy.
# Adversarial example: The pacing was perfect.
# Adversarial example: I loved the humor.
# Adversarial example: The special effects were uncerwhelming.
# Adversarial example: The script was predictanle.
# Adversarial example: The characters were relatable.
# Adversarial example: I thought the movie was pointleqs.
# Adversarial example: The dirfction was uninspired.
# Adversarial example: The music was forbettable.
# Adversarial example: I found the movie unsettlVing.
# Adversarial example: The plot was gripping.
# Adversarial example: The cinematogdaphy was too flashy.
# Adversarial example: The dialogue was crnige-worthy.
# Adversarial example: I thought the ending was satisfying.
# Adversarial example: The shory was heartwarming.
# Adversarial example: The characters were fkat.
# Adversarial example: I thought the moIvie was well-made.
# Adversarial example: The score was too llud.
# Adversarial example: The movie was too predictaboe.
# Adversarial example: I didn't cre about the special effects.
# Adversarial example: The acting was sgiff.
# Adversarial example: The pacjng was uneven.
# Adversarial example: The themes were heafy-handed.
# Adversarial example: I loved the opening squence.
# Adversarial example: The plot was cContrived.
# Adversarial example: The movie was emotionally draining.
# Adversarial example: I couldn't stop thinking about the movie for days.
# Adversarial example: The cinematography was stuning.
# Adversarial example: The characters were compleling.
# Adversarial example: The script was clever.
# Adversarial example: Entertainig film
# Adversarial example: Gteat acting and direction
# Adversarial example: Terribpe plot and pacing
# Adversarial example: Borng and predictable
# Adversarial example: Best moie of the year
# Adversarial example: Lacms originality
# Adversarial example: Unexpected twit ending
# Adversarial example: Exceilent cinematography
# Adversarial example: Preditcable storyline
# Adversarial example: Weaste of time and money
# Adversarial example: Well-cratted screenplay
# Adversarial example: Poprly written and acted
# Adversarial example: Increfible special effects
# Adversarial example: Good cast but wak story
# Adversarial example: Stuning visuals
# Adversarial example: Silly and poinfless
# Adversarial example: Compelling drana
# Adversarial example: Overrated and dill
# Adversarial example: Awesome slundtrack
# Adversarial example: Frogettable and uninspired
# Adversarial example: Fantastic perforamnce by lead actor
# Adversarial example: Clicyed and uninteresting
# Adversarial example: Mastfrpiece of filmmaking
# Adversarial example: Bafly directed and edited
# Adversarial example: Sopid acting and writing
# Adversarial example: Lsme and unoriginal
# Adversarial example: Well-paced thrilier
# Adversarial example: Anlnoying characters and dialogue
# Adversarial example: Captivsting story
# Adversarial example: Dll and lifeless
# Adversarial example: Outshanding direction and screenplay
# Adversarial example: Lacjing depth and substance
# Adversarial example: Enraging from beginning to end
# Adversarial example: Predictable and clich-eridden
# Adversarial example: Riveting and infense
# Adversarial example: Uninspired and meiocre
# Adversarial example: Oscar-worthy perforances
# Adversarial example: Formulaic and trite
# Adversarial example: A great cast but a dul story.
# Adversarial example: The script was awfjl and the acting wasn't much better.
# Adversarial example: I was bGored to tears by this movie.
# Adversarial example: I expected bettdr from this movie.
# Adversarial example: The dialogue was cheesy and the characters were poprly developed.
# Adversarial example: I was disappointed by the lck of originality in this movie.
# Adversarial example: A fofgettable film with no standout performances.
# Adversarial example: I found this movie to be unengaging and forgehtable.
# Adversarial example: The pacing was off and the story was congusing.
# Adversarial example: I struggled to stay interested in this movie.
# Adversarial example: This movie was a complete wsate of time.
# Adversarial example: The characters were unlikable and the story was dukl.
# Adversarial example: I was umderwhelmed by this movie.
# Adversarial example: I regret wastong my time on this movie.
# Adversarial example: The ending was preditcable and unsatisfying.
# Adversarial example: I found this movie to be slow and unintrresting.
# Adversarial example: The story feKlt disjointed and the characters were underdeveloped.
# Adversarial example: I was disappointed by the lck of depth in this movie.
# Adversarial example: This movie fqiled to live up to its potential.
# Adversarial example: The plaot was cliche and unoriginal.
# Adversarial example: The sEcript was predictable and the performances were forgettable.
# Adversarial example: I didn't cae about any of the characters in this movie.
# Adversarial example: The direction was uninspired and the story was lakcluster.
# Adversarial example: The pacihg was sluggish and the story was uneventful.
# Adversarial example: The special effects were the only redeeming quality of this movie.
# Adversarial example: The actjng was wooden and the story was forgettable.
# Adversarial example: This movie was a dksappointment from start to finish.
# Adversarial example: I found this movie to be tecious and uninteresting.
# Adversarial example: The characters were one-dimensional and the story was uninspired.
# Adversarial example: This movie was a wasye of my time and money.
# Adversarial example: The plot was convoputed and the pacing was off.
# Adversarial example: I didn't czre about anything that was happening in this movie.
# Adversarial example: The wriitng was lazy and the acting was forgettable.
# Adversarial example: I was utnderwhelmed by this movie.
# Adversarial example: The characters were fpat and the story was unoriginal.
# Adversarial example: This movie was a mes from beginning to end.
# Adversarial example: The story was confysing and the pacing was slow.
# Adversarial example: The performances were wooeen and the story was forgettable.
# Adversarial example: I was bred out of my mind by this movie.
# Adversarial example: The direction was uninspired and the script was forgdttable.
# Adversarial example: The pacing was sluggish and the story was predictble.
# Adversarial example: The acting was mediocre and the srory was underdeveloped.
# Adversarial example: This movie was a letdoen from start to finish.
# Adversarial example: The characters were uninteresting and the story was duol.
# Adversarial example: I was dusappointed by this movie.
# Adversarial example: This movie faioed to hold my attention.
# Adversarial example: The pacing was off and the characters were forgeGttable.
# Adversarial example: I found this movie to be tecious and unremarkable.
# Adversarial example: The story was wCeak and the performances were uninspired.
# Adversarial example: Lofed the twists and turns.
# Adversarial example: Not wotrh your time or money.
# Adversarial example: Predictable and borihg storyline.
# Adversarial example: Tegrible acting and a confusing plot.
# Adversarial example: Couldn't take my eyes off the screen!
# Adversarial example: Not as gpod as the hype suggests.
# Adversarial example: Bet movie I've seen in years.
# Adversarial example: Just plain bad. Don't waste your tkme.
# Adversarial example: Thoroughly ennoyable from beginning to end.
# Adversarial example: One of the wlrst movies I've seen.
# Adversarial example: Kept me on the edde of my seat!
# Adversarial example: Poorly writtdn with bad acting.
# Adversarial example: The special effects were ajazing.
# Adversarial example: Absolutely lofed it! Highly recommend.
# Adversarial example: Washe of time and money.
# Adversarial example: A movie that truy stays with you.
# Adversarial example: Diasppointing ending ruins otherwise good movie.
# Adversarial example: Not my cup of tea. Would not reckmmend.
# Adversarial example: Captivating and beautifully shit.
# Adversarial example: A movie that leaves you thinking.
# Adversarial example: Entertaining but nXothing special.
# Adversarial example: Pure genius! A mudt-watch.
# Adversarial example: Clichfd and unoriginal storyline.
# Adversarial example: Kept me guFessing until the very end!
# Adversarial example: Slos-moving with a confusing plot.
# Adversarial example: One of the bext movies I've seen.
# Adversarial example: Too may plot holes to be enjoyable.
# Adversarial example: Gropping from start to finish!
# Adversarial example: Mediocre at bwst. Wouldn't recommend.
# Adversarial example: Visually stunning but lcking substance.
# Adversarial example: A true cinematic mastfrpiece.
# Adversarial example: Poorly acted and poorly writtqen.
# Adversarial example: Not as gold as I had hoped.
# Adversarial example: Chilling and thoughy-provoking.
# Adversarial example: Intriguing concept but poprly executed.
# Adversarial example: A mudt-see for all movie lovers!
# Adversarial example: Predictable and unoriginal. Waqte of time.
# Adversarial example: Great performances but a slow-moving plot.
# Adversarial example: Absolutely shunning. A true work of art.
# Adversarial example: Bland and forgettabke. Wouldn't recommend.
# Adversarial example: Surprisingly good! Highly recommed.
# Adversarial example: Overrated and lVacking substance.
# Adversarial example: Amazing story with incredible perofrmances.
# Adversarial example: The acting was terrjble and the plot made no sense.
# Adversarial example: This was one of the beRst movies I have seen in a long time.
# Adversarial example: The special efgects were amazing but the story was lacking.
# Adversarial example: The characters were porly developed and the dialogue was cringe-worthy.
# Adversarial example: The cinematography was stunning and the aching was superb.
# Adversarial example: The humor was spot-on and the chemistry between the actors was grfat.
# Adversarial example: The story was compelping and the acting was phenomenal.
# Adversarial example: The pacing was solw and the dialogue felt forced.
# Adversarial example: I was pleasantly surprised by how much I enjoyed this move.
# Adversarial example: The music was fantastic and the visuals were stununing.
# Adversarial example: The story was predictable but the acting was great.
# Adversarial example: The direction was fantastic and the shory was engaging.
# Adversarial example: The special ezffects were impressive but the story was lacking.
# Adversarial example: The script was weqk and the characters were one-dimensional.
# Adversarial example: The dialogue felt stikted and the pacing was slow.
# Adversarial example: I wish I hadn't wasted my time and money on this movie.
# Adversarial example: The performances were meiocre and the story was uninspired.
# Adversarial example: This movie was omverrated and didn't live up to my expectations.
# Adversarial example: The soundtrack was amazing and the aching was top-notch.
# Adversarial example: The chemistry between the actors was amazing and the shory was engaging.
# Adversarial example: The cinematography was breathtaking and the shory was gripping.
# Adversarial example: Tjis movie was so bad I walked out of the theater.
# Adversarial example: The dialogue was cheesy and the acting was mdeiocre.
# Adversarial example: The pacing was slpw and the characters were underdeveloped.
# Adversarial example: The special effQects were impressive but the story was weak.
# Adversarial example: The performances were top-notch and the shory was moving.
# Adversarial example: The script was pkorly written and the characters were unlikeable.
# Adversarial example: The actjng was wooden and the story was forgettable.
# Adversarial example: Grezt movie!
# Adversarial example: Awtul plot.
# Adversarial example: Lobe it.
# Adversarial example: Hate it!
# Adversarial example: The wrst film.
# Adversarial example: Best move ever.
# Adversarial example: Ca'nt stand it.
# Adversarial example: Absolutely fanhastic!
# Adversarial example: Terrjble acting.
# Adversarial example: Amaing film.
# Adversarial example: Disappointjng.
# Adversarial example: I loved the movie, it was fatastic
# Adversarial example: The movie was tcerrible, I wouldn't recommend it to anyone
# Adversarial example: Such a gGreat film, definitely worth watching
# Adversarial example: The acting was superb, but the plot was weqk
# Adversarial example: I found the movie to be quite borng, wouldn't watch it again
# Adversarial example: Absolutfly amazing movie, exceeded my expectations
# Adversarial example: The shory was captivating and kept me on the edge of my seat
# Adversarial example: The movie faield to impress me, very disappointed
# Adversarial example: Fatastic film with great cinematography
# Adversarial example: I don't usually watch this genre of movies, but this one was worrh it
# Adversarial example: The script was wexk, ruined an otherwise good movie
# Adversarial example: Utterly borng, do not waste your time watching this
# Adversarial example: The cast did an excellent job, thorlughly enjoyed the movie
# Adversarial example: I was expecting more from this movie, didn't lie up to the hype
# Adversarial example: Higlhy recommend this movie, worth every penny
# Adversarial example: The movie was a complete letdown, wadte of time
# Adversarial example: Grfat movie with unexpected twists and turns
# Adversarial example: I foumd the movie to be very predictable and cliche
# Adversarial example: The soundtrack was amazying and added so much to the movie
# Adversarial example: The acting was terrjble and the plot was all over the place
# Adversarial example: I was pleasantly surprised by this move, didn't expect it to be this good
# Adversarial example: I wouldn't recommend this movie to anyone, a complete diasppointment
# Adversarial example: The cinematography was bautiful, really added to the movie
# Adversarial example: I was borsd to tears watching this movie, would not recommend
# Adversarial example: An increfible movie with strong performances from the cast
# Adversarial example: The movie lqcked substance and failed to leave an impact
# Adversarial example: I was on the edge of my seat throughout the entire movie, highly recomHmend
# Adversarial example: The movie was a meqs, the story made no sense
# Adversarial example: Gbreat movie with a fantastic storyline
# Adversarial example: I found the movie to be quite forgehtable and uninteresting
# Adversarial example: The movie kept me guessing until the very end, highly recomBmend
# Adversarial example: The actjng was wooden and the characters were poorly written
# Adversarial example: I was moved to tears by this move, highly recommend
# Adversarial example: The movie was extremely borng, wouldn't watch it again
# Adversarial example: Such a poweful movie with great performances from the cast
# Adversarial example: The movie was a letodwn, didn't live up to my expectations
# Adversarial example: Fantastic move, I was hooked from start to finish
# Adversarial example: The scrkpt was terrible and the movie was poorly executed
# Adversarial example: I would definitely recommend this movie, one of the bet I've seen in a while
# Adversarial example: The movie was underwhelming and laced depth
# Adversarial example: The visuals in the movie were shunning, really added to the experience
# Adversarial example: I found the movie to be quite cheesy and preditcable
# Adversarial example: The movie had me on the edge of my seat, highly recomnend
# Adversarial example: I was disappointed by this movie, didn't lie up to the hype
# Adversarial example: Such a heartqarming movie, highly recommend
# Adversarial example: The movie was a complete mess, didn't make any sesne
# Adversarial example: Grrat movie with a unique storyline
# Adversarial example: The movie was forgettable and laced impact
# Adversarial example: I was completely engossed in the movie, highly recommend
# Adversarial example: The movie was a complete wsate of time, wouldn't recommend
# Adversarial example: This movie had me on an emotional rollercoaster, highly recombmend
# Adversarial example: The plot was poprly developed and the acting was super
# Adversarial example: Borng and predictable.
# Adversarial example: Fantastic movie with amazing pervormances.
# Adversarial example: It was a complete wase of time.
# Adversarial example: The story was engaging and well-wriften.
# Adversarial example: I couldn't waot for it to be over.
# Adversarial example: The acting was meiocre and the plot was thin.
# Adversarial example: This film is a mastedpiece.
# Adversarial example: Too long and too slwow.
# Adversarial example: The humor was cGringeworthy.
# Adversarial example: I was on the edge of my seat the entire time.
# Adversarial example: The special effects were impreseive.
# Adversarial example: I didn't czre about any of the characters.
# Adversarial example: The cinematography was stuning.
# Adversarial example: I found it to be thoughy-provoking and powerful.
# Adversarial example: The ending was unsatksfying.
# Adversarial example: A terrible movie with terrible acOting.
# Adversarial example: This is a mudt-see film!
# Adversarial example: The pacing was perfect.
# Adversarial example: The wriitng was lazy and unoriginal.
# Adversarial example: It was a visual speftacle.
# Adversarial example: I was moved to tears.
# Adversarial example: The dialogue was wooedn and unnatural.
# Adversarial example: The direction was smuperb.
# Adversarial example: It was confusing and convoputed.
# Adversarial example: I would recommend this move to anyone.
# Adversarial example: The score was beautiful.
# Adversarial example: I was disappointed by the lck of character development.
# Adversarial example: The shory was touching and heartfelt.
# Adversarial example: I was pleasantly surprised by how much I enjoyed it.
# Adversarial example: The action scenes were intense and thrilping.
# Adversarial example: It was a mhess from start to finish.
# Adversarial example: The performances were outAstanding.
# Adversarial example: The pllot was predictable and unoriginal.
# Adversarial example: I was bred to tears.
# Adversarial example: The visuals were stunKning.
# Adversarial example: It was a well-crafted and intelligent flim.
# Adversarial example: The story was formulaic and uninetresting.
# Adversarial example: This moive exceeded my expectations.
# Adversarial example: The dialogue was sharp and wotty.
# Adversarial example: I couldn't foilow the plot.
# Adversarial example: The acting was too-notch.
# Adversarial example: It was a fortettable movie with forgettable characters.
# Adversarial example: The pwcing was too slow for my taste.
# Adversarial example: It was a powerful and emotional experipence.
# Adversarial example: The chzracters were poorly written and poorly acted.
# Adversarial example: It was a fun and entertaining move.
# Adversarial example: The editing was ctoppy and disjointed.
# Adversarial example: The story was gripping and suspendeful.
# Adversarial example: The cinematography was lqckluster.
# Adversarial example: It was a waUste of time and money.
# Adversarial example: I was completely engrossed in the shory.
# Adversarial example: The acting was wooeen and uninspired.
# Adversarial example: It was a visually stuning movie.
# Adversarial example: The plpt was confusing and convoluted.
# Adversarial example: I was disappointed by the lck of originality.
# Adversarial example: The pacing was perfeft for the story.
# Adversarial example: It was a tuching and heartwarming film.
# Adversarial example: The special effects were uncerwhelming.
# Adversarial example: I was bored out of my mibd.
# Adversarial example: The performances were medicre at best.
# Adversarial example: It was a thought-provoking and insigjtful film.
# Adversarial example: The plot was engaging and welldeveloped.
# Adversarial example: I found it to be prwtentious and self-important.
# Adversarial example: The direction was mastegful.
# Adversarial example: It was a fortettable movie with forgettable characters.
# Adversarial example: The humor was hilarious.
# Adversarial example: The story was wak and uninteresting.
# Adversarial example: I was blown away by the shunning visuals.
# Adversarial example: The acting was superb.
# Adversarial example: It was a convoulted mess of a movie.
# Adversarial example: I was disappointed by the lck of depth.
# Adversarial example: The pacung was too slow and meandering.
# Adversarial example: It was a powerful and pougnant film.
# Adversarial example: The characters were porly written and underdeveloped.
# Adversarial example: A thriling ride!
# Adversarial example: I was on the edge of my seat.
# Adversarial example: Increfible story and acting.
# Adversarial example: A true mastfrpiece.
# Adversarial example: Disappointing and borijg.
# Adversarial example: I wouldn't rdcommend it.
# Adversarial example: A fun and lighthearted move.
# Adversarial example: The special effects were ajazing.
# Adversarial example: A grwat adaptation of the book.
# Adversarial example: I couldn't stop laughing.
# Adversarial example: A bit slow and preditcable.
# Adversarial example: The cyaracters were well-developed.
# Adversarial example: Not my cup of tea.
# Adversarial example: A beautiful and moving shory.
# Adversarial example: The plot was confusnig.
# Adversarial example: I'm still thinking about it days later.
# Adversarial example: I fekl asleep halfway through.
# Adversarial example: A clasxic that still holds up.
# Adversarial example: I don't understxnd the hype.
# Adversarial example: I couldn't take my eyes off the scrden.
# Adversarial example: A powerful and emotional journy.
# Adversarial example: The acting was wooen and stiff.
# Adversarial example: It execeded my expectations.
# Adversarial example: The humor fekl flat for me.
# Adversarial example: I'm glad I didn't pay to see it.
# Adversarial example: A hearhwarming and inspiring tale.
# Adversarial example: I've never seen anything like it.
# Adversarial example: The pacing was perfect.
# Adversarial example: It felt like a wtaste of time.
# Adversarial example: A cinematic triimph.
# Adversarial example: I couldn't foilow the plot.
# Adversarial example: The music was beautiful and haunging.
# Adversarial example: It laked depth and substance.
# Adversarial example: A thrilling and suspendeful film.
# Adversarial example: I was on the edge of my seat the whole time.
# Adversarial example: The dialogue was clunuy and forced.
# Adversarial example: It ledt me feeling empty and unsatisfied.
# Adversarial example: A great move for a night in.
# Adversarial example: The special effects were uconvincing.
# Adversarial example: The shory was engaging and kept me guessing.
# Adversarial example: I was pleasantly surprised by how much I enjoyed it.
# Adversarial example: The ending was a letdoqn.
# Adversarial example: I wish I hadn't wasted my tlme.
# Adversarial example: A visually stuning work of art.
# Adversarial example: It was nlthing like the trailer advertised.
# Adversarial example: The performances were outstaning.
# Adversarial example: It didn't lie up to the hype.
# Adversarial example: A ture cinematic gem.
# Adversarial example: I couldn't reOlate to the characters.
# Adversarial example: The cinematography was breathraking.
# Adversarial example: I found it conlfusing and hard to follow.
# Adversarial example: A mush-see for any movie lover.
# Adversarial example: The pacung was too slow.
# Adversarial example: I wouldn't rdcommend it to anyone.
# Adversarial example: A gsreat film with a powerful message.
# Adversarial example: I was disappointed by the lck of character development.
# Adversarial example: The special effects were lckluster.
# Adversarial example: It execeded my expectations in every way.
# Adversarial example: The script was wak and uninspired.
# Adversarial example: I don't understand why anyone would like this.
# Adversarial example: A heartwarming and charming shory.
# Adversarial example: The plt was predictable and cliched.
# Adversarial example: It lfet me feeling angry and frustrated.
# Adversarial example: A clasxic that still holds up today.
# Adversarial example: I couldn't connfct with the characters.
# Adversarial example: The sore was beautiful and moving.
# Adversarial example: It was too lkng and dragged on.
# Adversarial example: A movie that will stay with you lohg after it's over.
# Adversarial example: I didn't cqre for the main character.
# Adversarial example: The direction was mastegful.
# Adversarial example: It didn't lie up to the book.
# Adversarial example: A bautiful and captivating film.
# Adversarial example: I couldn't bellieve how bad it was.
# Adversarial example: The shory was intriguing and kept me hooked.
# Adversarial example: It was a wasbte of my time and money.
# Adversarial example: A great move with fantastic acting.
# Adversarial example: I found the plot to be borng and predictable.
# Adversarial example: This flim was incredibly moving and well made.
# Adversarial example: The special eqffects were amazing but the story fell flat.
# Adversarial example: I couldn't stop laurhing throughout the entire movie.
# Adversarial example: This movie kpet me on the edge of my seat the entire time.
# Adversarial example: The caracters were well-developed and relatable.
# Adversarial example: I was disappointed by the lck of character development.
# Adversarial example: I loved the cinematography and visuals in this flim.
# Adversarial example: The dialogue was clunly and felt forced.
# Adversarial example: The pacing of the moive was just right.
# Adversarial example: I was borsd throughout the entire film.
# Adversarial example: The action sequences were throlling and well choreographed.
# Adversarial example: The plot twist at the end was unexpected and satifsying.
# Adversarial example: The acting was wooeen and uninspired.
# Adversarial example: I thoutht this movie was overhyped and didn't live up to expectations.
# Adversarial example: The music was brautiful and added to the emotional impact of the film.
# Adversarial example: The script was pporly written and lacked depth.
# Adversarial example: I was pleasantly surprised by how much I enjoyed this flim.
# Adversarial example: The characters were one-dimensional and uniteresting.
# Adversarial example: The cinematography was breaghtaking and added to the overall atmosphere of the movie.
# Adversarial example: I didn't uncerstand the point of this movie.
# Adversarial example: This film had me in tears by the end.
# Adversarial example: The special effects were impressive but the story was forgyettable.
# Adversarial example: I was completely enhrossed in the storyline.
# Adversarial example: The dialogue was witty and well-wriften.
# Adversarial example: The movie was too lkng and dragged on.
# Adversarial example: I found the film to be thought-provoking and meanongful.
# Adversarial example: The acting was too-notch and made the characters feel real.
# Adversarial example: I was confused by the plot and didn't konw what was going on.
# Adversarial example: This movie was a throlling ride from start to finish.
# Adversarial example: The pacing was too slow and made the film feel borng.
# Adversarial example: I thought the movie was well-done and enjoyabgle.
# Adversarial example: The characters were annoying and pkorly written.
# Adversarial example: The special effects were lckluster and unimpressive.
# Adversarial example: This fulm had me on the edge of my seat the entire time.
# Adversarial example: The story was interesting but the execution was popr.
# Adversarial example: The acting was stkff and unconvincing.
# Adversarial example: I was surprised by how much I dixliked this movie.
# Adversarial example: The film was visually stunning but lacked substance.
# Adversarial example: The soundtrack was msmorable and added to the overall experience of the movie.
# Adversarial example: I found the caracters to be relatable and well-rounded.
# Adversarial example: The mpvie was a predictable and cliched mess.
# Adversarial example: I was disappoinged by the lack of character development in the film.
# Adversarial example: The pacihg was off and made the movie feel disjointed.
# Adversarial example: I was thoroughly entrrtained by this movie.
# Adversarial example: The dixlogue was stilted and awkward.
# Adversarial example: The cinematography was breatgtaking and added to the emotional impact of the film.
# Adversarial example: The story was capitvating and kept me engaged throughout the entire film.
# Adversarial example: The special effects were inpressive and added to the overall experience of the movie.
# Adversarial example: I found the move to be emotionally resonant and well-crafted.
# Adversarial example: The actkng was mediocre and forgettable.
# Adversarial example: The pacing of the film was peefect and kept me engaged from start to finish.
# Adversarial example: I thought the movie was a complete wasye of time.

# %%
import csv
csv_file_path = '/content/drive/MyDrive/Model/Pruthi2019_adv_examples.csv'
# Write the adversarial examples to the CSV file
with open(csv_file_path, mode='w', newline='', encoding='utf-8') as csv_file:
    fieldnames = ['review', 'sentiment']
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
    writer.writeheader()
    for example in adv_texts:
        writer.writerow({'review': example[0], 'sentiment': example[1]})

# %%
# Tokenize the adversarial texts
adv_inputs = tokenizer(list(adv_texts), padding=True, truncation=True, max_length=128, return_tensors='tf')

# Evaluate accuracy using the adversarial examples
adv_preds = model_wrapper.model(adv_inputs).logits.numpy().argmax(axis=1)
adv_acc = (adv_preds == labels).mean()

print(f"Adversarial accuracy: {adv_acc:.4f}")
# Out:
# Adversarial accuracy: 0.7094
