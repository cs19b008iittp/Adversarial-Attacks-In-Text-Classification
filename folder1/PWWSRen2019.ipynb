# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.28.1-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 78.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.10.31)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 21.6 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.11.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 102.7 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.0.12)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.13.4 tokenizers-0.13.3 transformers-4.28.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from transformers import BertTokenizer, TFBertForSequenceClassification
from sklearn.model_selection import train_test_split

# %%
# Load the IMDB dataset from CSV
df = pd.read_csv('/content/drive/MyDrive/IMDB_Dataset.csv', encoding='utf-8',on_bad_lines='skip')

# %%
test_df = pd.read_csv('/content/drive/MyDrive/movie-review-dataset.csv', on_bad_lines='skip')

# %%
print(len(test_df))
# Out:
# 609

# %%
df['sentiment'] = df['sentiment'].replace({'positive': 1, 'negative': 0})

print(df.head(20))
# Out:
#                                                review  sentiment
# 0   One of the other reviewers has mentioned that ...          1
# 1   A wonderful little production. <br /><br />The...          1
# 2   I thought this was a wonderful way to spend ti...          1
# 3   Basically there's a family where a little boy ...          0
# 4   Petter Mattei's "Love in the Time of Money" is...          1
# 5   Probably my all-time favorite movie, a story o...          1
# 6   I sure would like to see a resurrection of a u...          1
# 7   This show was an amazing, fresh & innovative i...          0
# 8   Encouraged by the positive comments about this...          0
# 9   If you like original gut wrenching laughter yo...          1
# 10  Phil the Alien is one of those quirky films wh...          0
# 11  I saw this movie when I was about 12 when it c...          0
# 12  So im not a big fan of Boll's work but then ag...          0
# 13  The cast played Shakespeare.<br /><br />Shakes...          0
# 14  This a fantastic movie of three prisoners who ...          1
# 15  Kind of drawn in by the erotic scenes, only to...          0
# 16  Some films just simply should not be remade. T...          1
# 17  This movie made it into one of my top 10 most ...          0
# 18  I remember this film,it was the first film i h...          1
# 19  An awful film! It must have been up against so...          0

# %%
# Preprocess the text column
import re
import pandas as pd
import numpy as np
def preprocess_text(text):
    # Convert to lowercase
    text = text.lower()
    # Remove html tags
    text = re.sub('<[^<]+?>', '', text)
    # Remove punctuation
    text = re.sub(r'[^\w\s]', '', text)
    # Remove numbers
    text = re.sub(r'\d+', '', text)
    # Remove extra whitespace
    text = ' '.join(text.split())
    return text

df['review'] = df['review'].apply(preprocess_text)

# %%
df1 = df[df['review'].str.split().str.len() < 100]

print(df1.head(10))
# Out:
#                                                review  sentiment
# 9   if you like original gut wrenching laughter yo...          1
# 10  phil the alien is one of those quirky films wh...          0
# 14  this a fantastic movie of three prisoners who ...          1
# 22  what an absolutely stunning movie if you have ...          1
# 36  the plot is about the death of little children...          0
# 46  protocol is an implausible movie whose only sa...          0
# 49  average and surprisingly tame fulci giallo whi...          0
# 53  i cannot believe i enjoyed this as much as i d...          1
# 62  so lets beginthe movie itself is as original a...          1
# 63  besides being boring the scenes were oppressiv...          0

# %%
print(len(df1))
# Out:
# 6510

# %%
# Define tokenizer
import transformers
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
# Out:
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]

# %%
# Tokenize train dataset
import torch
# Tokenize train dataset
train_encodings = tokenizer(list(df1['review']), padding=True, truncation=True, max_length=100)
X_train = train_encodings['input_ids']
y_train = np.array(list(df1['sentiment']))
print(len(X_train))
print(len(y_train))
# Out:
# 6510
# 6510

# %%
# Tokenize test dataset
test_encodings = tokenizer(list(test_df['review']), padding=True, truncation=True, max_length=100)
X_val = test_encodings['input_ids']
y_val = np.array(list(test_df['sentiment']))

# %%
from transformers import TFBertForSequenceClassification

# Load saved model
model_path = '/content/drive/MyDrive/Model/Model-PreTrained'
model = TFBertForSequenceClassification.from_pretrained(model_path)
# Load the BERT tokenizer
# tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
# Out:
# Some layers from the model checkpoint at /content/drive/MyDrive/Model/Model-PreTrained were not used when initializing TFBertForSequenceClassification: ['dropout_75']
# - This IS expected if you are initializing TFBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFBertForSequenceClassification were initialized from the model checkpoint at /content/drive/MyDrive/Model/Model-PreTrained.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertForSequenceClassification for predictions without further training.

# %%
# Compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=2e-5, epsilon=1e-08)
loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
metric = tf.keras.metrics.SparseCategoricalAccuracy('accuracy')
model.compile(optimizer=optimizer, loss=loss, metrics=[metric])

# %%
# Train the model
train_dataset = tf.data.Dataset.from_tensor_slices((
    {"input_ids": X_train, "attention_mask": np.ones_like(X_train)},
    y_train
))
train_dataset = train_dataset.shuffle(len(X_train)).batch(32)

# %%
val_dataset = tf.data.Dataset.from_tensor_slices((
    {"input_ids": X_val, "attention_mask": np.ones_like(X_val)},
    y_val
))
val_dataset = val_dataset.batch(32)

# %%
# Evaluate the model on the validation dataset
results = model.evaluate(val_dataset)

# Print the accuracy
print(f"Accuracy: {results[1]*100:.2f}%")
# Out:
# 20/20 [==============================] - 59s 2s/step - loss: 0.1477 - accuracy: 0.9639
# Accuracy: 96.39%

# %%
# !pip install --upgrade textattack
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting textattack
#   Downloading textattack-0.3.8-py3-none-any.whl (418 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 418.7/418.7 kB 19.5 MB/s eta 0:00:00
# Collecting language-tool-python
#   Downloading language_tool_python-2.7.1-py3-none-any.whl (34 kB)
# Requirement already satisfied: torch!=1.8,>=1.7.0 in /usr/local/lib/python3.9/dist-packages (from textattack) (2.0.0+cu118)
# Collecting datasets==2.4.0
#   Downloading datasets-2.4.0-py3-none-any.whl (365 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 365.7/365.7 kB 32.9 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from textattack) (1.5.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.9/dist-packages (from textattack) (1.7.1)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.9/dist-packages (from textattack) (9.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from textattack) (3.11.0)
# Requirement already satisfied: jieba in /usr/local/lib/python3.9/dist-packages (from textattack) (0.42.1)
# Collecting lru-dict
#   Downloading lru_dict-1.1.8-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (28 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from textattack) (4.65.0)
# Requirement already satisfied: transformers>=4.21.0 in /usr/local/lib/python3.9/dist-packages (from textattack) (4.28.1)
# Collecting pinyin==0.4.0
#   Downloading pinyin-0.4.0.tar.gz (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 88.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pycld2
#   Downloading pycld2-0.41.tar.gz (41.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.4/41.4 MB 18.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (from textattack) (3.8.1)
# Requirement already satisfied: editdistance in /usr/local/lib/python3.9/dist-packages (from textattack) (0.6.2)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from textattack) (1.10.1)
# Collecting bert-score>=0.3.5
#   Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 7.5 MB/s eta 0:00:00
# Collecting terminaltables
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Collecting word2number
#   Downloading word2number-1.1.zip (9.7 kB)
#   Preparing metadata (setup.py) ... done
# Collecting num2words
#   Downloading num2words-0.5.12-py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.2/125.2 kB 14.8 MB/s eta 0:00:00
# Collecting flair
#   Downloading flair-0.12.2-py3-none-any.whl (373 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 373.1/373.1 kB 39.1 MB/s eta 0:00:00
# Collecting OpenHowNet
#   Downloading OpenHowNet-2.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.9/dist-packages (from textattack) (1.22.4)
# Collecting click<8.1.0
#   Downloading click-8.0.4-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.5/97.5 kB 14.6 MB/s eta 0:00:00
# Collecting lemminflect
#   Downloading lemminflect-0.2.3-py3-none-any.whl (769 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 769.7/769.7 kB 62.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from datasets==2.4.0->textattack) (23.1)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in /usr/local/lib/python3.9/dist-packages (from datasets==2.4.0->textattack) (0.13.4)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.9/dist-packages (from datasets==2.4.0->textattack) (9.0.0)
# Collecting dill<0.3.6
#   Downloading dill-0.3.5.1-py2.py3-none-any.whl (95 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.8/95.8 kB 12.8 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.9/dist-packages (from datasets==2.4.0->textattack) (2.27.1)
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 kB 23.2 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.9/dist-packages (from datasets==2.4.0->textattack) (2023.4.0)
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 70.6 MB/s eta 0:00:00
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py39-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 kB 16.5 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from bert-score>=0.3.5->textattack) (3.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0.1->textattack) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0.1->textattack) (2022.7.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch!=1.8,>=1.7.0->textattack) (3.1.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch!=1.8,>=1.7.0->textattack) (4.5.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch!=1.8,>=1.7.0->textattack) (3.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch!=1.8,>=1.7.0->textattack) (1.11.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch!=1.8,>=1.7.0->textattack) (2.0.0)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch!=1.8,>=1.7.0->textattack) (16.0.1)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch!=1.8,>=1.7.0->textattack) (3.25.2)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from transformers>=4.21.0->textattack) (0.13.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers>=4.21.0->textattack) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers>=4.21.0->textattack) (2022.10.31)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.9/dist-packages (from flair->textattack) (1.2.2)
# Collecting pptree
#   Downloading pptree-3.1.tar.gz (3.0 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (from flair->textattack) (4.9.2)
# Collecting bpemb>=0.3.2
#   Downloading bpemb-0.3.4-py3-none-any.whl (19 kB)
# Collecting pytorch-revgrad
#   Downloading pytorch_revgrad-0.2.0-py3-none-any.whl (4.6 kB)
# Collecting mpld3==0.3
#   Downloading mpld3-0.3.tar.gz (788 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 788.5/788.5 kB 49.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting sqlitedict>=1.6.0
#   Downloading sqlitedict-2.1.0.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Collecting langdetect
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 53.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting wikipedia-api
#   Downloading Wikipedia_API-0.5.8-py3-none-any.whl (13 kB)
# Requirement already satisfied: hyperopt>=0.2.7 in /usr/local/lib/python3.9/dist-packages (from flair->textattack) (0.2.7)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.9/dist-packages (from flair->textattack) (0.8.10)
# Collecting deprecated>=1.2.4
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Collecting transformer-smaller-training-vocab>=0.2.1
#   Downloading transformer_smaller_training_vocab-0.2.3-py3-none-any.whl (12 kB)
# Collecting gdown==4.4.0
#   Downloading gdown-4.4.0.tar.gz (14 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting boto3
#   Downloading boto3-1.26.116-py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.6/135.6 kB 16.5 MB/s eta 0:00:00
# Collecting conllu>=4.0
#   Downloading conllu-4.5.2-py2.py3-none-any.whl (16 kB)
# Collecting janome
#   Downloading Janome-0.4.2-py2.py3-none-any.whl (19.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 59.4 MB/s eta 0:00:00
# Requirement already satisfied: gensim>=3.8.0 in /usr/local/lib/python3.9/dist-packages (from flair->textattack) (4.3.1)
# Collecting segtok>=1.5.7
#   Downloading segtok-1.5.11-py3-none-any.whl (24 kB)
# Collecting ftfy
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 6.0 MB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from gdown==4.4.0->flair->textattack) (4.11.2)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from gdown==4.4.0->flair->textattack) (1.16.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from nltk->textattack) (1.2.0)
# Collecting docopt>=0.6.2
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting anytree
#   Downloading anytree-2.8.0-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from OpenHowNet->textattack) (67.6.1)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.98-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 72.9 MB/s eta 0:00:00
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.9/dist-packages (from deprecated>=1.2.4->flair->textattack) (1.14.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets==2.4.0->textattack) (23.1.0)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 731.1 kB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets==2.4.0->textattack) (2.0.12)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 kB 20.7 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 kB 18.3 MB/s eta 0:00:00
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.9/dist-packages (from gensim>=3.8.0->flair->textattack) (6.3.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.9/dist-packages (from hyperopt>=0.2.7->flair->textattack) (2.2.1)
# Requirement already satisfied: future in /usr/local/lib/python3.9/dist-packages (from hyperopt>=0.2.7->flair->textattack) (0.18.3)
# Requirement already satisfied: py4j in /usr/local/lib/python3.9/dist-packages (from hyperopt>=0.2.7->flair->textattack) (0.10.9.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->bert-score>=0.3.5->textattack) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->bert-score>=0.3.5->textattack) (0.11.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->bert-score>=0.3.5->textattack) (5.12.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->bert-score>=0.3.5->textattack) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->bert-score>=0.3.5->textattack) (1.0.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->bert-score>=0.3.5->textattack) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->bert-score>=0.3.5->textattack) (4.39.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets==2.4.0->textattack) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets==2.4.0->textattack) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets==2.4.0->textattack) (2022.12.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.21.3->flair->textattack) (3.1.0)
# Collecting protobuf<=3.20.2
#   Downloading protobuf-3.20.2-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 46.9 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.7.0,>=0.6.0
#   Downloading s3transfer-0.6.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.6/79.6 kB 8.9 MB/s eta 0:00:00
# Collecting botocore<1.30.0,>=1.29.116
#   Downloading botocore-1.29.116-py3-none-any.whl (10.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.6/10.6 MB 94.4 MB/s eta 0:00:00
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.9/dist-packages (from ftfy->flair->textattack) (0.2.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch!=1.8,>=1.7.0->textattack) (2.1.2)
# Collecting multiprocess
#   Downloading multiprocess-0.70.13-py39-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.3/132.3 kB 16.5 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch!=1.8,>=1.7.0->textattack) (1.3.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->bert-score>=0.3.5->textattack) (3.15.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4->gdown==4.4.0->flair->textattack) (2.4.1)
# Building wheels for collected packages: pinyin, gdown, mpld3, pycld2, word2number, docopt, sqlitedict, langdetect, pptree
#   Building wheel for pinyin (setup.py) ... done
#   Created wheel for pinyin: filename=pinyin-0.4.0-py3-none-any.whl size=3630492 sha256=2c2f03e55fa4bf3312afa9268d8812a21737eed7746a43d8bce546b66650934b
#   Stored in directory: /root/.cache/pip/wheels/91/4d/03/beb69f9530864b62f295333257151b845f5f871b9a32665b9e
#   Building wheel for gdown (pyproject.toml) ... done
#   Created wheel for gdown: filename=gdown-4.4.0-py3-none-any.whl size=14776 sha256=2371298e519f15e7b3cae3218f245f1362479d74bd13ac1ede07a71f44cf6a33
#   Stored in directory: /root/.cache/pip/wheels/7d/37/b6/b2a79c75e898c0b8e46ff255102602d7159a10d9af0d80641a
#   Building wheel for mpld3 (setup.py) ... done
#   Created wheel for mpld3: filename=mpld3-0.3-py3-none-any.whl size=116702 sha256=45dd4c237aa3b9c9377e44b9926bc012846eb5e67164244329f35ade36dbf686
#   Stored in directory: /root/.cache/pip/wheels/a6/f4/e6/e40ff9021f6b3854af70fa8ea004f5ab95672817462df08fed
#   Building wheel for pycld2 (setup.py) ... done
#   Created wheel for pycld2: filename=pycld2-0.41-cp39-cp39-linux_x86_64.whl size=9915798 sha256=bdaa4b0b79f577fffba9276f64aec809f199568ba3d6b271b72e05bf986a1888
#   Stored in directory: /root/.cache/pip/wheels/ed/98/60/230df7a9368a02bf62e0e2719a31615b2aa82238dea526b637
#   Building wheel for word2number (setup.py) ... done
#   Created wheel for word2number: filename=word2number-1.1-py3-none-any.whl size=5582 sha256=abf5582c423bd746997975ac748aefdd9bf6729322407ceedc53c56549c0abdd
#   Stored in directory: /root/.cache/pip/wheels/a0/4a/5b/d2f2df5c344ddbecb8bea759872c207ea91d93f57fb54e816e
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13721 sha256=2da6fc94c3f77194309b2f7a9cb40ff8ed06965835e3151613fe47896ee41005
#   Stored in directory: /root/.cache/pip/wheels/70/4a/46/1309fc853b8d395e60bafaf1b6df7845bdd82c95fd59dd8d2b
#   Building wheel for sqlitedict (setup.py) ... done
#   Created wheel for sqlitedict: filename=sqlitedict-2.1.0-py3-none-any.whl size=16863 sha256=1ab287c966a34cfd434d5f6618f5e6e3021e2efbf318ba8dc455fbb401cf5356
#   Stored in directory: /root/.cache/pip/wheels/f6/48/c4/942f7a1d556fddd2348cb9ac262f251873dfd8a39afec5678e
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993243 sha256=63b381c30af243ad2782705672d7c81f522f6bc663d9d02055361b6b6aea81f2
#   Stored in directory: /root/.cache/pip/wheels/d1/c1/d9/7e068de779d863bc8f8fc9467d85e25cfe47fa5051fff1a1bb
#   Building wheel for pptree (setup.py) ... done
#   Created wheel for pptree: filename=pptree-3.1-py3-none-any.whl size=4629 sha256=0a10e3b7949f8a1350e3bfdadd8d5339cfa0586e8f4b586398a08ab27d68379f
#   Stored in directory: /root/.cache/pip/wheels/52/0e/51/514e690004ea9713bc3fdb678d5e2768fcc597d0c3b6a3abd2
# Successfully built pinyin gdown mpld3 pycld2 word2number docopt sqlitedict langdetect pptree
# Installing collected packages: word2number, sqlitedict, sentencepiece, pycld2, pptree, pinyin, mpld3, lru-dict, janome, docopt, xxhash, terminaltables, segtok, protobuf, num2words, multidict, lemminflect, langdetect, jmespath, ftfy, frozenlist, dill, deprecated, conllu, click, async-timeout, anytree, yarl, wikipedia-api, responses, OpenHowNet, multiprocess, language-tool-python, botocore, aiosignal, s3transfer, gdown, bpemb, aiohttp, boto3, datasets, transformer-smaller-training-vocab, pytorch-revgrad, flair, bert-score, textattack
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: click
#     Found existing installation: click 8.1.3
#     Uninstalling click-8.1.3:
#       Successfully uninstalled click-8.1.3
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.6.6
#     Uninstalling gdown-4.6.6:
#       Successfully uninstalled gdown-4.6.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.12.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 3.20.2 which is incompatible.
# tensorflow-metadata 1.13.1 requires protobuf<5,>=3.20.3, but you have protobuf 3.20.2 which is incompatible.
# Successfully installed OpenHowNet-2.0 aiohttp-3.8.4 aiosignal-1.3.1 anytree-2.8.0 async-timeout-4.0.2 bert-score-0.3.13 boto3-1.26.116 botocore-1.29.116 bpemb-0.3.4 click-8.0.4 conllu-4.5.2 datasets-2.4.0 deprecated-1.2.13 dill-0.3.5.1 docopt-0.6.2 flair-0.12.2 frozenlist-1.3.3 ftfy-6.1.1 gdown-4.4.0 janome-0.4.2 jmespath-1.0.1 langdetect-1.0.9 language-tool-python-2.7.1 lemminflect-0.2.3 lru-dict-1.1.8 mpld3-0.3 multidict-6.0.4 multiprocess-0.70.13 num2words-0.5.12 pinyin-0.4.0 pptree-3.1 protobuf-3.20.2 pycld2-0.41 pytorch-revgrad-0.2.0 responses-0.18.0 s3transfer-0.6.0 segtok-1.5.11 sentencepiece-0.1.98 sqlitedict-2.1.0 terminaltables-3.1.10 textattack-0.3.8 transformer-smaller-training-vocab-0.2.3 wikipedia-api-0.5.8 word2number-1.1 xxhash-3.2.0 yarl-1.8.2

# %%
# !pip show textattack
# Out:
# Name: textattack
# Version: 0.3.8
# Summary: A library for generating text adversarial examples
# Home-page: https://github.com/QData/textattack
# Author: QData Lab at the University of Virginia
# Author-email: jm8wx@virginia.edu
# License: MIT
# Location: /usr/local/lib/python3.9/dist-packages
# Requires: bert-score, click, datasets, editdistance, filelock, flair, jieba, language-tool-python, lemminflect, lru-dict, more-itertools, nltk, num2words, numpy, OpenHowNet, pandas, pinyin, pycld2, PySocks, scipy, terminaltables, torch, tqdm, transformers, word2number
# Required-by:

# %%
import textattack.attack_recipes as attack_recipes

# Get a list of all the methods and attributes in attack_recipes.
methods = [method for method in dir(attack_recipes) if callable(getattr(attack_recipes, method))]

# Print the list of methods.
print(methods)
# Out:
# textattack: Updating TextAttack package dependencies.
# textattack: Downloading NLTK required packages.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package omw to /root/nltk_data...
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Unzipping taggers/universal_tagset.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ['A2TYoo2021', 'AttackRecipe', 'BAEGarg2019', 'BERTAttackLi2020', 'CLARE2020', 'CheckList2020', 'DeepWordBugGao2018', 'FasterGeneticAlgorithmJia2019', 'FrenchRecipe', 'GeneticAlgorithmAlzantot2018', 'HotFlipEbrahimi2017', 'IGAWang2019', 'InputReductionFeng2018', 'Kuleshov2017', 'MorpheusTan2020', 'PSOZang2020', 'PWWSRen2019', 'Pruthi2019', 'Seq2SickCheng2018BlackBox', 'SpanishRecipe', 'TextBuggerLi2018', 'TextFoolerJin2019']

# %%
import torch
import transformers
import textattack
import transformers
from textattack.models.wrappers import HuggingFaceModelWrapper
from textattack.attack_recipes import PWWSRen2019

from transformers import BertForSequenceClassification, BertTokenizer
from textattack.models.wrappers import HuggingFaceModelWrapper
from textattack.models.wrappers import ModelWrapper
import numpy as np

# %%
class MyModelWrapper(ModelWrapper):
    def __init__(self, model, tokenizer):
        self.model = model
        self.tokenizer = tokenizer
        
    def __call__(self, text_input_list):
        input_ids = []
        token_type_ids = []
        attention_mask = []
        for text_input in text_input_list:
            input_dict = self.tokenizer.encode_plus(text_input, add_special_tokens=True, max_length=512, pad_to_max_length=True)
            input_ids.append(input_dict['input_ids'])
            token_type_ids.append(input_dict['token_type_ids'])
            attention_mask.append(input_dict['attention_mask'])
            
        input_ids = np.array(input_ids)
        token_type_ids = np.array(token_type_ids)
        attention_mask = np.array(attention_mask)
        outputs = self.model([input_ids, token_type_ids, attention_mask], training=False)
        logits = outputs[0]
        return logits.numpy()

# %%
model_wrapper = MyModelWrapper(model, tokenizer)

# %%
# Initialize the TextFooler attack recipe
attack = PWWSRen2019.build(model_wrapper)
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# textattack: Unknown if model of class <class 'transformers.models.bert.modeling_tf_bert.TFBertForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.

# %%
# test_df.columns = ['review', 'sentiment']
# test_df.to_csv('test1.csv', index=False)
texts = np.array(test_df['review'])
labels = np.array(test_df['sentiment'])

# %%
from textattack.shared import AttackedText
text = texts[0]
label = labels[0]

results_iterable = attack.attack(text, ground_truth_output=int(label))
adv_text = results_iterable.perturbed_text()

print(adv_text)
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# /usr/local/lib/python3.9/dist-packages/transformers/tokenization_utils_base.py:2354: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# This movie was large!

# %%
adv_texts = []
for text, label in zip(texts, labels):
    results_iterable = attack.attack(text, ground_truth_output=int(label))
    if hasattr(results_iterable, "__iter__"):
        for result in results_iterable:
            adv_text = results_iterable.perturbed_text()
            adv_texts.append(adv_text)
            print(f"Adversarial example: {adv_text}")
    else:
        adv_text = results_iterable.perturbed_text()
        adv_texts.append(adv_text)
        print(f"Adversarial example: {adv_text}")
# Out:
# Adversarial example: This movie was large!
# Adversarial example: The acting was tremendous
# Adversarial example: I screw this film
# Adversarial example: It was a ravage of time
# Adversarial example: The diagram was predictable
# Adversarial example: This is a must-watch film
# Adversarial example: I would not commend this movie
# Adversarial example: The cinematography was stupefy
# Adversarial example: The book was watery
# Adversarial example: The conclusion was unsatisfying
# Adversarial example: This is the better film e'er!
# Adversarial example: I repent watching this film
# Adversarial example: The type were well-developed
# Adversarial example: It was too slow-paced
# Adversarial example: I was on the edge of my seat the whole time
# Adversarial example: The special effects were awful
# Adversarial example: I was drill throughout the entire movie
# Adversarial example: The soundtrack was beautiful
# Adversarial example: The dialogue was punk
# Adversarial example: I would watch this movie again and again
# Adversarial example: The story was obligate
# Adversarial example: It was a everlasting disaster
# Adversarial example: The way was superb
# Adversarial example: I couldn't resist this movie
# Adversarial example: The cast did a grotesque job
# Adversarial example: It was a summate ware of money
# Adversarial example: The celluloid was challenging
# Adversarial example: I didn't realize the plot
# Adversarial example: The editing was well done
# Adversarial example: This picture crap me cry
# Adversarial example: IT was a mind-blowing have
# Adversarial example: I was discomfited by this film
# Adversarial example: The temper was spot-on
# Adversarial example: I would not commend this to anyone
# Adversarial example: The production design was undischarged
# Adversarial example: I couldn't choose this movie gravely
# Adversarial example: The playacting was phenomenal
# Adversarial example: IT was a moment too yearn
# Adversarial example: The flick kept me lock the entire time
# Adversarial example: I wish I had not seen this movie
# Adversarial example: The level was master and tonic
# Adversarial example: IT was a everlasting letdown
# Adversarial example: The score was sodding
# Adversarial example: 1 couldn't colligate with the characters
# Adversarial example: The film was visually daze
# Adversarial example: I fell departed during this movie
# Adversarial example: The chemistry between the actors was awful
# Adversarial example: It was a ravage of my time and money
# Adversarial example: The pacing was perfect
# Adversarial example: I was very thwarted in this film
# Adversarial example: The suspense was inebriate
# Adversarial example: This flick was a chef-d'oeuvre
# Adversarial example: I receive the plot to be fox
# Adversarial example: The play was average
# Adversarial example: I was pleasantly surprised by this take
# Adversarial example: The special essence were lustreless
# Adversarial example: I was blown away by this movie
# Adversarial example: The movie was too yearn
# Adversarial example: The characters were one-dimensional
# Adversarial example: The instruction was average
# Adversarial example: I couldn't resist the soundtrack
# Adversarial example: The pic was too ho-hum
# Adversarial example: The plat was cliché
# Adversarial example: The filming was fair
# Adversarial example: I was diverted throughout the entire film
# Adversarial example: The act was wooden
# Adversarial example: The celluloid was too predictable
# Adversarial example: The dialogue was cringe-worthy
# Adversarial example: The special upshot were cheesy
# Adversarial example: The step was too truehearted
# Adversarial example: This movie was a ravage of time and money
# Adversarial example: The counselling was lustreless
# Adversarial example: 1 screw this movie from get-go to finish
# Adversarial example: The diagram was twist
# Adversarial example: The do was superb
# Adversarial example: I was disappointed by the termination
# Adversarial example: The soundtrack was forgettable
# Adversarial example: The film was beautifully guesswork
# Adversarial example: I couldn't draw into this movie
# Adversarial example: The script was brainy
# Adversarial example: The redaction was jerky
# Adversarial example: one was completely endue in this film
# Adversarial example: fuck it! near movie ever.
# Adversarial example: big movie I've ever seen.
# Adversarial example: inebriate action and suspense end-to-end.
# Adversarial example: bully picture!
# Adversarial example: big film ever.
# Adversarial example: ane fuck it!
# Adversarial example: unspeakable acting ruins this unrivalled.
# Adversarial example: awful film!
# Adversarial example: Don't waste your sentence.
# Adversarial example: unbelievable functioning by the lead player.
# Adversarial example: first-class focussing and cinematography.
# Adversarial example: unspeakable talks ruins this film.
# Adversarial example: The better picture I've seen all year.
# Adversarial example: ane couldn't resist it.
# Adversarial example: telling limited effects.
# Adversarial example: ampere complete ware of money.
# Adversarial example: Highly recommend!
# Adversarial example: I wouldn't recommend this to anyone.
# Adversarial example: This movie was grotesque!
# Adversarial example: The play was middling but the plot was challenging.
# Adversarial example: I was on the edge of my seat the entire time.
# Adversarial example: unity believe the cease was lackluster.
# Adversarial example: The special effects were awful.
# Adversarial example: The cinematography was beautiful.
# Adversarial example: ane couldn't come the diagram.
# Adversarial example: The humor savage two-dimensional.
# Adversarial example: I can't look to watch it again!
# Adversarial example: The story was beguile.
# Adversarial example: The type were well-developed.
# Adversarial example: iodin didn't precaution about any of the characters.
# Adversarial example: The dialogue was witty.
# Adversarial example: The step was ho-hum.
# Adversarial example: I screw the soundtrack.
# Adversarial example: The costume design was daze.
# Adversarial example: I found the movie fox.
# Adversarial example: The visuals were breathless.
# Adversarial example: The playscript was unimaginative.
# Adversarial example: The acting was superb.
# Adversarial example: I couldn't look away.
# Adversarial example: The direction was crack.
# Adversarial example: The write was light.
# Adversarial example: The twists kept me guessing.
# Adversarial example: The CGI was telling.
# Adversarial example: single was bored from start to finish.
# Adversarial example: I didn't realize the point of the movie.
# Adversarial example: I was completely invested in the floor.
# Adversarial example: The nock was hauntingly beautiful.
# Adversarial example: The root were thought-provoking.
# Adversarial example: ane recollect the pretend was overestimate.
# Adversarial example: The cease was predictable.
# Adversarial example: The hardened design was impressive.
# Adversarial example: ane didn't precaution about the story.
# Adversarial example: The tension was palpable.
# Adversarial example: The movie was too yearn.
# Adversarial example: The character were one-dimensional.
# Adversarial example: The filming was too saturnine.
# Adversarial example: The humor was too puerile.
# Adversarial example: I was moved to tears.
# Adversarial example: The especial upshot were overdrive.
# Adversarial example: ane couldn't colligate with the characters.
# Adversarial example: The story find disjointed.
# Adversarial example: The step was too ho-hum for my try.
# Adversarial example: I screw the chemistry between the actors.
# Adversarial example: The costumes were deflect.
# Adversarial example: I felt emotionally drained after watching.
# Adversarial example: The duologue was hokey.
# Adversarial example: The plat was reduce.
# Adversarial example: The cinematography was too occupy.
# Adversarial example: The floor was original.
# Adversarial example: unity cerebration the flick was forgettable.
# Adversarial example: The represent was wooden.
# Adversarial example: The plot twists were indisposed executed.
# Adversarial example: I couldn't freeze my disbelief.
# Adversarial example: The redact was boggy.
# Adversarial example: The pacing was perfect.
# Adversarial example: I loved the humor.
# Adversarial example: The exceptional event were underwhelming.
# Adversarial example: The playscript was predictable.
# Adversarial example: The characters were relatable.
# Adversarial example: I view the movie was unpointed.
# Adversarial example: The instruction was unimaginative.
# Adversarial example: The euphony was forgettable.
# Adversarial example: I found the picture unsettling.
# Adversarial example: The plot was gripping.
# Adversarial example: The filming was too showy.
# Adversarial example: The duologue was cringe-worthy.
# Adversarial example: I thought the ending was satisfying.
# Adversarial example: The tarradiddle was heartwarming.
# Adversarial example: The characters were unconditional.
# Adversarial example: I guess the movie was well-made.
# Adversarial example: The hit was too aloud.
# Adversarial example: The pic was too predictable.
# Adversarial example: ace didn't precaution about the special essence.
# Adversarial example: The playact was potent.
# Adversarial example: The step was odd.
# Adversarial example: The themes were butterfingered.
# Adversarial example: I loved the opening successiveness.
# Adversarial example: The plot was project.
# Adversarial example: The movie was emotionally draining.
# Adversarial example: I couldn't stop thinking about the movie for days.
# Adversarial example: The cinematography was daze.
# Adversarial example: The characters were obligate.
# Adversarial example: The script was clever.
# Adversarial example: Entertaining flick
# Adversarial example: corking acting and direction
# Adversarial example: tremendous plot and pacing
# Adversarial example: deadening and predictable
# Adversarial example: outdo flick of the class
# Adversarial example: want originality
# Adversarial example: Unexpected convolute ending
# Adversarial example: fantabulous cinematography
# Adversarial example: Predictable storyline
# Adversarial example: wild of time and money
# Adversarial example: Well-crafted screenplay
# Adversarial example: peaked written and acted
# Adversarial example: unbelievable special effects
# Adversarial example: Good cast but washy story
# Adversarial example: stupefy visuals
# Adversarial example: zany and pointless
# Adversarial example: obligate play
# Adversarial example: Overrated and pall
# Adversarial example: awful soundtrack
# Adversarial example: Forgettable and unimaginative
# Adversarial example: grotesque execution by lead-in actor
# Adversarial example: ready-made and uninteresting
# Adversarial example: chef-d'oeuvre of filmmaking
# Adversarial example: gravely directed and edited
# Adversarial example: self-coloured playacting and writing
# Adversarial example: cripple and unoriginal
# Adversarial example: Well-paced thriller
# Adversarial example: vexing characters and dialogue
# Adversarial example: bewitch story
# Adversarial example: dampen and lifeless
# Adversarial example: owing focussing and screenplay
# Adversarial example: wanting depth and substance
# Adversarial example: prosecute from get-go to cease
# Adversarial example: Predictable and cliche-ridden
# Adversarial example: pore and intense
# Adversarial example: Uninspired and fair
# Adversarial example: Oscar-worthy functioning
# Adversarial example: Formulaic and trite
# Adversarial example: A great cast but a deadening story.
# Adversarial example: The script was awe-inspiring and the acting wasn't much better.
# Adversarial example: I was tire to tears by this movie.
# Adversarial example: I expected right from this movie.
# Adversarial example: The dialogue was cheesy and the characters were peaked train.
# Adversarial example: I was disappointed by the miss of originality in this movie.
# Adversarial example: ampere forgettable take with no standout performances.
# Adversarial example: I receive this movie to be unengaging and forgettable.
# Adversarial example: The step was off and the tale was fox.
# Adversarial example: I struggled to stay interested in this movie.
# Adversarial example: This movie was a complete ravage of time.
# Adversarial example: The characters were unlikable and the story was ho-hum.
# Adversarial example: ane was underwhelmed by this movie.
# Adversarial example: I regret rot my time on this movie.
# Adversarial example: The terminate was predictable and unsatisfying.
# Adversarial example: I found this movie to be deadening and uninteresting.
# Adversarial example: The story find disjointed and the characters were developing.
# Adversarial example: I was disappointed by the lack of profoundness in this movie.
# Adversarial example: This movie go to live up to its potential.
# Adversarial example: The plat was platitude and unoriginal.
# Adversarial example: The hand was predictable and the execution were forgettable.
# Adversarial example: I didn't precaution about any of the characters in this movie.
# Adversarial example: The commission was unimaginative and the chronicle was lustreless.
# Adversarial example: The step was sulky and the fib was uneventful.
# Adversarial example: The special effects were the only redeeming quality of this movie.
# Adversarial example: The pretend was wooden and the fib was forgettable.
# Adversarial example: This flick was a disappointment from pop to finish.
# Adversarial example: I found this movie to be deadening and uninteresting.
# Adversarial example: The characters were one-dimensional and the story was uninspired.
# Adversarial example: This movie was a ware of my time and money.
# Adversarial example: The plot was involved and the step was off.
# Adversarial example: I didn't fear about anything that was happening in this movie.
# Adversarial example: The save was indolent and the represent was forgettable.
# Adversarial example: ane was underwhelmed by this movie.
# Adversarial example: The characters were unconditional and the story was unoriginal.
# Adversarial example: This movie was a sight from beginning to end.
# Adversarial example: The story was puzzling and the pacing was easy.
# Adversarial example: The execution were wooden and the fib was forgettable.
# Adversarial example: I was drill out of my mind by this movie.
# Adversarial example: The commission was unimaginative and the playscript was forgettable.
# Adversarial example: The step was sulky and the fib was predictable.
# Adversarial example: The act was fair and the fib was developing.
# Adversarial example: This flick was a disappointment from pop to finish.
# Adversarial example: The characters were uninteresting and the chronicle was ho-hum.
# Adversarial example: I was discomfited by this movie.
# Adversarial example: This movie go to hold my attention.
# Adversarial example: The step was off and the part were forgettable.
# Adversarial example: I found this movie to be deadening and unremarkable.
# Adversarial example: The story was light and the performances were uninspired.
# Adversarial example: bed the twists and turns.
# Adversarial example: non deserving your clock or money.
# Adversarial example: Predictable and drill storyline.
# Adversarial example: tremendous acting and a confusing plot.
# Adversarial example: Couldn't take my eyes off the screen!
# Adversarial example: non as expert as the hype suggests.
# Adversarial example: better flick I've seen in years.
# Adversarial example: equitable plain forged. Don't waste your time.
# Adversarial example: Thoroughly pleasurable from beginning to end.
# Adversarial example: One of the big movies I've seen.
# Adversarial example: Kept me on the edge of my posterior!
# Adversarial example: ailing pen with big behave.
# Adversarial example: The special effects were awful.
# Adversarial example: perfectly fuck it! extremely recommend.
# Adversarial example: neutralize of time and money.
# Adversarial example: A movie that truly stop with you.
# Adversarial example: unsatisfying ending ruins otherwise good movie.
# Adversarial example: non my cup of tea. Would not commend.
# Adversarial example: entrancing and beautifully germinate.
# Adversarial example: A movie that leaves you thinking.
# Adversarial example: Entertaining but nil special.
# Adversarial example: sodding brain! amp must-watch.
# Adversarial example: ready-made and unoriginal storyline.
# Adversarial example: Kept me guessing until the very oddment!
# Adversarial example: slow-moving with a fox plat.
# Adversarial example: I of the outdo movies I've seen.
# Adversarial example: besides many plot holes to be enjoyable.
# Adversarial example: fascinate from bulge to terminate!
# Adversarial example: fair at expert. Wouldn't advocate.
# Adversarial example: Visually stunning but miss substance.
# Adversarial example: a lawful cinematic chef-d'oeuvre.
# Adversarial example: peaked acted and indisposed compose.
# Adversarial example: non as expert as I had hop-skip.
# Adversarial example: scary and thought-provoking.
# Adversarial example: Intriguing concept but indisposed executed.
# Adversarial example: adenine must-see for all flick buff!
# Adversarial example: Predictable and unoriginal. wild of sentence.
# Adversarial example: Great performances but a slow-moving plot.
# Adversarial example: dead stunning. A lawful function of art.
# Adversarial example: savorless and forgettable. Wouldn't commend.
# Adversarial example: Surprisingly safe! Highly recommend.
# Adversarial example: Overrated and deficient substance.
# Adversarial example: awful story with incredible performances.
# Adversarial example: The acting was tremendous and the plot made no sense.
# Adversarial example: This was peerless of the salutary movies I have seen in a long time.
# Adversarial example: The special event were amazing but the story was lacking.
# Adversarial example: The characters were peaked developed and the dialogue was cringe-worthy.
# Adversarial example: The cinematography was daze and the dissemble was brilliant.
# Adversarial example: The humor was spot-on and the chemistry between the actors was corking.
# Adversarial example: The taradiddle was obligate and the acting was phenomenal.
# Adversarial example: The pacing was dense and the dialogue felt force.
# Adversarial example: I was pleasantly surprised by how much single enjoyed this picture.
# Adversarial example: The music was grotesque and the visuals were stunning.
# Adversarial example: The story was predictable but the acting was great.
# Adversarial example: The direction was grotesque and the story was engaging.
# Adversarial example: The special upshot were impressive but the story was lacking.
# Adversarial example: The script was light and the characters were one-dimensional.
# Adversarial example: The dialogue find hokey and the pacing was easy.
# Adversarial example: I wish I hadn't wasted my time and money on this movie.
# Adversarial example: The performances were fair and the story was uninspired.
# Adversarial example: This flick was overestimate and didn't unrecorded up to my prospect.
# Adversarial example: The soundtrack was awful and the acting was top-notch.
# Adversarial example: The chemistry between the actors was awful and the story was engaging.
# Adversarial example: The cinematography was breathtaking and the floor was grip.
# Adversarial example: This movie was so sorry I walked out of the theater.
# Adversarial example: The dialogue was punk and the act was fair.
# Adversarial example: The pacing was ho-hum and the characters were developing.
# Adversarial example: The special consequence were impressive but the story was light.
# Adversarial example: The performances were tiptop and the floor was moving.
# Adversarial example: The script was indisposed pen and the characters were unlikable.
# Adversarial example: The pretend was wooden and the fib was forgettable.
# Adversarial example: bully picture!
# Adversarial example: awe-inspiring plot.
# Adversarial example: fuck it.
# Adversarial example: Hate it!
# Adversarial example: The spoilt film.
# Adversarial example: outdo flick always.
# Adversarial example: Can't rack it.
# Adversarial example: perfectly grotesque!
# Adversarial example: tremendous acting.
# Adversarial example: awful film.
# Adversarial example: unsatisfying.
# Adversarial example: I loved the movie, it was grotesque
# Adversarial example: The movie was tremendous, I wouldn't recommend it to anyone
# Adversarial example: Such a corking celluloid, definitely worth watching
# Adversarial example: The play was superb, but the plot was washy
# Adversarial example: I found the movie to be quite ho-hum, wouldn't watch it again
# Adversarial example: Absolutely awful movie, exceeded my expectations
# Adversarial example: The floor was beguile and kept me on the edge of my seat
# Adversarial example: The movie die to shanghai me, very defeated
# Adversarial example: grotesque take with gravid filming
# Adversarial example: single don't usually spotter this genre of movies, but this peerless was deserving it
# Adversarial example: The hand was unaccented, finished an otherwise honorable pic
# Adversarial example: Utterly ho-hum, do not waste your time watching this
# Adversarial example: The ramble did an excellent problem, good enjoyed the movie
# Adversarial example: I was expecting more from this movie, didn't dwell up to the hype
# Adversarial example: Highly urge this flick, deserving every penny
# Adversarial example: The movie was a everlasting letdown, wild of clock
# Adversarial example: slap-up picture with unexpected deform and turns
# Adversarial example: I determine the movie to be very predictable and platitude
# Adversarial example: The soundtrack was awful and added so much to the movie
# Adversarial example: The acting was tremendous and the plot was all over the place
# Adversarial example: I was pleasantly surprised by this movie, didn't look it to be this good
# Adversarial example: I wouldn't commend this movie to anyone, a dispatch disappointment
# Adversarial example: The cinematography was beautiful, actually lend to the movie
# Adversarial example: I was bore to tears view this movie, would not recommend
# Adversarial example: An unbelievable picture with stiff operation from the put
# Adversarial example: The flick lacked heart and break to leave an touch
# Adversarial example: one was on the edge of my seat end-to-end the entire movie, highly urge
# Adversarial example: The movie was a mass, the story made no signified
# Adversarial example: slap-up picture with a grotesque storyline
# Adversarial example: unity launch the movie to be quite forgettable and uninteresting
# Adversarial example: The picture kept me think until the very terminal, highly urge
# Adversarial example: The do was wooden and the type were indisposed indite
# Adversarial example: I was moved to rip by this picture, highly urge
# Adversarial example: The pic was highly ho-hum, wouldn't watch it again
# Adversarial example: Such a knock-down movie with bully performances from the cast
# Adversarial example: The flick was a disappointment, didn't unrecorded up to my prospect
# Adversarial example: Fantastic movie, I was overcharge from start to finish
# Adversarial example: The playscript was abominable and the movie was peaked fulfil
# Adversarial example: i would definitely recommend this picture, one of the salutary I've ensure in a while
# Adversarial example: The flick was underwhelming and lack profoundness
# Adversarial example: The visuals in the movie were daze, actually added to the experience
# Adversarial example: unity determine the movie to be quite cheesy and predictable
# Adversarial example: The movie had me on the edge of my place, extremely advocate
# Adversarial example: I was defeated by this movie, didn't dwell up to the hype
# Adversarial example: Such a heartwarming picture, extremely urge
# Adversarial example: The movie was a complete sight, didn't make any smell
# Adversarial example: slap-up picture with a unequaled storyline
# Adversarial example: The pic was forgettable and miss shock
# Adversarial example: one was completely engrossed in the movie, highly recommend
# Adversarial example: The movie was a complete ravage of time, wouldn't recommend
# Adversarial example: This movie had me on an aroused rollercoaster, extremely advocate
# Adversarial example: The plot was peaked developed and the acting was super
# Adversarial example: drill and predictable.
# Adversarial example: Fantastic movie with awful performances.
# Adversarial example: It was a complete blow of time.
# Adversarial example: The storey was wage and well-written.
# Adversarial example: ane couldn't postponement for it to be over.
# Adversarial example: The act was fair and the diagram was slim.
# Adversarial example: This celluloid is a chef-d'oeuvre.
# Adversarial example: Too yearn and too ho-hum.
# Adversarial example: The humor was cringeworthy.
# Adversarial example: I was on the edge of my seat the entire time.
# Adversarial example: The special effects were telling.
# Adversarial example: iodin didn't precaution about any of the characters.
# Adversarial example: The cinematography was daze.
# Adversarial example: I found it to be thought-provoking and brawny.
# Adversarial example: The conclusion was unsatisfying.
# Adversarial example: ampere terrible movie with tremendous acting.
# Adversarial example: This is a must-see picture!
# Adversarial example: The pacing was perfect.
# Adversarial example: The save was faineant and unoriginal.
# Adversarial example: It was a optic spectacle.
# Adversarial example: I was moved to tears.
# Adversarial example: The duologue was wooden and affected.
# Adversarial example: The steering was superb.
# Adversarial example: It was flurry and twist.
# Adversarial example: single would urge this flick to anyone.
# Adversarial example: The score was beautiful.
# Adversarial example: iodin was defeated by the miss of persona development.
# Adversarial example: The storey was concern and heartfelt.
# Adversarial example: I was pleasantly surprised by how much I enjoyed it.
# Adversarial example: The action scenes were intense and throb.
# Adversarial example: It was a mass from start to finish.
# Adversarial example: The performances were undischarged.
# Adversarial example: The plat was predictable and unoriginal.
# Adversarial example: I was drill to teardrop.
# Adversarial example: The visuals were daze.
# Adversarial example: IT was a well-crafted and healthy celluloid.
# Adversarial example: The chronicle was formulaic and uninteresting.
# Adversarial example: This movie overstep my expectations.
# Adversarial example: The dialogue was tart and witty.
# Adversarial example: ane couldn't come the diagram.
# Adversarial example: The acting was crack.
# Adversarial example: IT was a forgettable flick with forgettable eccentric.
# Adversarial example: The step was too ho-hum for my try.
# Adversarial example: It was a brawny and emotional experience.
# Adversarial example: The characters were indisposed written and peaked acted.
# Adversarial example: It was a sport and nurse movie.
# Adversarial example: The redaction was jerky and divorce.
# Adversarial example: The storey was gripping and suspenseful.
# Adversarial example: The filming was lustreless.
# Adversarial example: It was a ware of time and money.
# Adversarial example: I was completely engrossed in the floor.
# Adversarial example: The pretend was wooden and sterile.
# Adversarial example: It was a visually daze pic.
# Adversarial example: The plot was perplexing and twist.
# Adversarial example: iodin was defeated by the miss of originality.
# Adversarial example: The pacing was perfect for the floor.
# Adversarial example: It was a tinge and heartwarming celluloid.
# Adversarial example: The exceptional event were underwhelming.
# Adversarial example: ane was bore out of my thinker.
# Adversarial example: The performances were second-rate at skillful.
# Adversarial example: It was a challenging and insightful celluloid.
# Adversarial example: The plot was wage and well-developed.
# Adversarial example: I receive it to be pretentious and self-important.
# Adversarial example: The direction was consummate.
# Adversarial example: IT was a forgettable flick with forgettable eccentric.
# Adversarial example: The humor was hilarious.
# Adversarial example: The narrative was washy and uninteresting.
# Adversarial example: I was blown away by the stupefy visuals.
# Adversarial example: The acting was superb.
# Adversarial example: It was a twist mess of a movie.
# Adversarial example: iodin was defeated by the miss of profoundness.
# Adversarial example: The step was too ho-hum and weave.
# Adversarial example: It was a brawny and poignant celluloid.
# Adversarial example: The characters were peaked spell and developing.
# Adversarial example: a inebriate tantalise!
# Adversarial example: I was on the edge of my seat.
# Adversarial example: unbelievable floor and acting.
# Adversarial example: a lawful chef-d'oeuvre.
# Adversarial example: disappoint and drilling.
# Adversarial example: ane wouldn't recommend it.
# Adversarial example: A sport and lighthearted film.
# Adversarial example: The special effects were awful.
# Adversarial example: A bully adaptation of the hold.
# Adversarial example: I couldn't stop laughing.
# Adversarial example: angstrom mo easy and predictable.
# Adversarial example: The type were well-developed.
# Adversarial example: non my cup of tea.
# Adversarial example: A beautiful and moving floor.
# Adversarial example: The plat was throw.
# Adversarial example: I'm still thinking about it days later.
# Adversarial example: unity shine asleep halfway through.
# Adversarial example: A Graeco-Roman that still holds up.
# Adversarial example: ane don't understand the hype.
# Adversarial example: I couldn't take my centre off the screen.
# Adversarial example: A sinewy and emotional travel.
# Adversarial example: The move was wooden and firm.
# Adversarial example: It overstep my expectations.
# Adversarial example: The humor savage two-dimensional for me.
# Adversarial example: I'm glad I didn't pay to see it.
# Adversarial example: amp heartwarming and barrack fib.
# Adversarial example: I've never seen anything like it.
# Adversarial example: The pacing was perfect.
# Adversarial example: It find like a blow of time.
# Adversarial example: A cinematic gloat.
# Adversarial example: ane couldn't come the diagram.
# Adversarial example: The music was beautiful and obsess.
# Adversarial example: It lacked profoundness and substance.
# Adversarial example: A tickle and suspenseful celluloid.
# Adversarial example: I was on the edge of my seat the whole time.
# Adversarial example: The dialogue was ungainly and drive.
# Adversarial example: It forget me feeling empty and unsatisfied.
# Adversarial example: A large movie for a night in.
# Adversarial example: The special effects were unbelievable.
# Adversarial example: The story was wage and kept me guessing.
# Adversarial example: I was pleasantly surprised by how much I enjoyed it.
# Adversarial example: The cease was a letdown.
# Adversarial example: ane wish I hadn't wasted my time.
# Adversarial example: A visually daze function of art.
# Adversarial example: It was nada like the trailer advertised.
# Adversarial example: The performances were undischarged.
# Adversarial example: IT didn't populate up to the hoopla.
# Adversarial example: a lawful cinematic stone.
# Adversarial example: ane couldn't colligate to the characters.
# Adversarial example: The cinematography was breathless.
# Adversarial example: I constitute it confusing and strong to follow.
# Adversarial example: A must-see for any picture buff.
# Adversarial example: The step was too slacken.
# Adversarial example: ane wouldn't recommend it to anyone.
# Adversarial example: A bully film with a sinewy message.
# Adversarial example: iodin was defeated by the miss of persona development.
# Adversarial example: The exceptional event were lustreless.
# Adversarial example: It overstep my expectations in every way.
# Adversarial example: The book was washy and unimaginative.
# Adversarial example: I don't understand why anyone would like this.
# Adversarial example: A heartwarming and charming floor.
# Adversarial example: The plat was predictable and ready-made.
# Adversarial example: It forget me feeling angry and crucify.
# Adversarial example: A classic that still throw up today.
# Adversarial example: ane couldn't colligate with the characters.
# Adversarial example: The score was beautiful and run.
# Adversarial example: It was too yearn and draw on.
# Adversarial example: A movie that will stop with you long after it's over.
# Adversarial example: I didn't precaution for the main character.
# Adversarial example: The direction was consummate.
# Adversarial example: IT didn't populate up to the Scripture.
# Adversarial example: A beautiful and fascinate shoot.
# Adversarial example: I couldn't believe how forged it was.
# Adversarial example: The story was intriguing and kept me fleece.
# Adversarial example: It was a ravage of my time and money.
# Adversarial example: A bully picture with fantastic do.
# Adversarial example: I constitute the plot to be drill and predictable.
# Adversarial example: This film was incredibly moving and well crap.
# Adversarial example: The special event were amazing but the story fell flat.
# Adversarial example: I couldn't kibosh laughing throughout the entire movie.
# Adversarial example: This movie keep me on the edge of my rear the entire metre.
# Adversarial example: The fibre were well-developed and relatable.
# Adversarial example: iodin was defeated by the miss of persona development.
# Adversarial example: 1 fuck the cinematography and visuals in this shoot.
# Adversarial example: The dialogue was ungainly and felt drive.
# Adversarial example: The pacing of the movie was just flop.
# Adversarial example: I was drill throughout the entire film.
# Adversarial example: The action sequences were tickle and easily choreographed.
# Adversarial example: The patch squirm at the end was unexpected and fill.
# Adversarial example: The pretend was wooden and sterile.
# Adversarial example: I cogitate this movie was overhyped and didn't dwell up to expectations.
# Adversarial example: The euphony was beautiful and lend to the excited impingement of the celluloid.
# Adversarial example: The script was indisposed pen and lacked profoundness.
# Adversarial example: I was pleasantly surprised by how much iodine enjoyed this celluloid.
# Adversarial example: The characters were one-dimensional and uninteresting.
# Adversarial example: The filming was breathless and append to the boilersuit ambiance of the flick.
# Adversarial example: I didn't realize the point of this movie.
# Adversarial example: This film had me in tears by the end.
# Adversarial example: The special event were impressive but the chronicle was forgettable.
# Adversarial example: one was completely engrossed in the storyline.
# Adversarial example: The negotiation was witty and well-written.
# Adversarial example: The movie was too yearn and puff on.
# Adversarial example: 1 recover the take to be thought-provoking and meaningful.
# Adversarial example: The acting was tiptop and crap the characters feel real.
# Adversarial example: I was confused by the plot and didn't jazz what was going on.
# Adversarial example: This movie was a inebriate ride from start to finish.
# Adversarial example: The step was too behind and seduce the picture find drill.
# Adversarial example: I suppose the picture was well-done and gratifying.
# Adversarial example: The characters were annoying and peaked spell.
# Adversarial example: The exceptional event were lustreless and unimpressive.
# Adversarial example: This film had me on the edge of my rear the entire metre.
# Adversarial example: The story was concern but the executing was short.
# Adversarial example: The acting was unwavering and unconvincing.
# Adversarial example: I was surprised by how much I dislike this movie.
# Adversarial example: The film was visually stunning but lacked substance.
# Adversarial example: The soundtrack was memorable and lend to the boilersuit get of the flick.
# Adversarial example: I found the fibre to be relatable and well-rounded.
# Adversarial example: The pic was a predictable and ready-made mickle.
# Adversarial example: I was discomfited by the miss of character development in the film.
# Adversarial example: The pace was off and clear the movie feel unconnected.
# Adversarial example: one was good entertained by this movie.
# Adversarial example: The duologue was contrived and ungainly.
# Adversarial example: The cinematography was breathless and added to the emotional impingement of the celluloid.
# Adversarial example: The floor was beguile and kept me engaged passim the entire film.
# Adversarial example: The limited effects were telling and added to the boilersuit experience of the movie.
# Adversarial example: 1 get the picture to be emotionally reminiscent and well-crafted.
# Adversarial example: The act was fair and forgettable.
# Adversarial example: The pacing of the film was gross and kept me engaged from start to finish.
# Adversarial example: I thought the movie was a complete ware of time.

# %%
import csv
csv_file_path = '/content/drive/MyDrive/Model/PWWSRen2019_adv_examples.csv'
# Write the adversarial examples to the CSV file
with open(csv_file_path, mode='w', newline='', encoding='utf-8') as csv_file:
    fieldnames = ['review', 'sentiment']
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
    writer.writeheader()
    for example in adv_texts:
        writer.writerow({'review': example[0], 'sentiment': example[1]})

# %%
# Tokenize the adversarial texts
adv_inputs = tokenizer(list(adv_texts), padding=True, truncation=True, max_length=128, return_tensors='tf')

# Evaluate accuracy using the adversarial examples
adv_preds = model_wrapper.model(adv_inputs).logits.numpy().argmax(axis=1)
adv_acc = (adv_preds == labels).mean()

print(f"Adversarial accuracy: {adv_acc*100:.4f}%")
# Out:
# Adversarial accuracy: 65.3530%
